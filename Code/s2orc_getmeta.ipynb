# %%
import os
import gzip
import json
import pandas as pd
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
directory = '/Volumes/Samsung_T5/S2ORC'

# %%
metadata = []

# %%
gz_files = [f for f in os.listdir(directory) if f.endswith('.gz') and not f.startswith('.')]

# %%
i = 0
length = len(gz_files)
for gz_file in gz_files:
    i += 1
    # #testing with a single file
    # if i > 1:
    #     break
    print(f"Processing {gz_file} ({i}/{length})")
    with gzip.open(os.path.join(directory, gz_file), 'rt') as f:
        for line in f:
            data = json.loads(line)
            # Extract the required entries
            entries = { 'corpusid': data.get('corpusid'),
                       'externalids': data.get('externalids'),
                       'source': data.get('content', {}).get('source')}
            metadata.append(entries)
# Out:
# Processing 20240126_122714_00094_7rzhv_0001e621-8ad9-4d43-ae8d-164f447c10ee.gz (1/264)
# Processing 20240126_122714_00094_7rzhv_00422a22-c682-4dc5-9f60-058bc6275887.gz (2/264)
# Processing 20240126_122714_00094_7rzhv_00699fcf-3365-403c-97f0-ef3a1eb175fc.gz (3/264)
# Processing 20240126_122714_00094_7rzhv_009a2917-4b60-4082-b5f3-0a161d89db66.gz (4/264)
# Processing 20240126_122714_00094_7rzhv_00d6d748-21a3-4006-9a2a-0048b0b0a447.gz (5/264)
# Processing 20240126_122714_00094_7rzhv_01807ef4-25a8-4bda-849d-821050636a32.gz (6/264)
# Processing 20240126_122714_00094_7rzhv_01d581ad-d41f-4ee0-92ae-2feb96407870.gz (7/264)
# Processing 20240126_122714_00094_7rzhv_01e9983f-5fac-42cd-a387-c6ca046a606c.gz (8/264)
# Processing 20240126_122714_00094_7rzhv_0231ac23-f77c-4733-bb83-e395c60972d1.gz (9/264)
# Processing 20240126_122714_00094_7rzhv_0278aadb-a64b-41ed-b0db-35d5b4563e7a.gz (10/264)
# Processing 20240126_122714_00094_7rzhv_0279797f-de5d-41de-abaa-acd1efd752b6.gz (11/264)
# Processing 20240126_122714_00094_7rzhv_03e2f4da-898d-4b54-bc93-175aa1db9769.gz (12/264)
# Processing 20240126_122714_00094_7rzhv_04c4686a-baf8-4ea9-b903-6265a44f21ca.gz (13/264)
# Processing 20240126_122714_00094_7rzhv_06c00fe5-37f9-4b7e-9ac9-4bbcaf1d5391.gz (14/264)
# Processing 20240126_122714_00094_7rzhv_073894ac-222b-4250-bb38-01b500ab5361.gz (15/264)
# Processing 20240126_122714_00094_7rzhv_07aa40c9-0d57-4c67-a8fc-13f84e855bee.gz (16/264)
# Processing 20240126_122714_00094_7rzhv_0aec67c3-a88c-4a1a-9bfe-957960a4a98d.gz (17/264)
# Processing 20240126_122714_00094_7rzhv_0b19ecff-5c60-47ad-ad32-a17eeee031ae.gz (18/264)
# Processing 20240126_122714_00094_7rzhv_0be2e936-d46b-45f0-809d-c78efc058672.gz (19/264)
# Processing 20240126_122714_00094_7rzhv_0c36b984-2c4b-4164-b90b-d73071caef95.gz (20/264)
# Processing 20240126_122714_00094_7rzhv_0cf24f87-a71d-459a-a1dd-c7c67ac0f842.gz (21/264)
# Processing 20240126_122714_00094_7rzhv_0d14f3ca-aeff-4815-8c53-2ace830161c3.gz (22/264)
# Processing 20240126_122714_00094_7rzhv_e53ae68b-d130-4271-97e8-cbec6066ab0e.gz (238/264)
# Processing 20240126_122714_00094_7rzhv_e69f3bd1-c83f-4ca7-bcd4-3dfc1f4db60e.gz (239/264)
# Processing 20240126_122714_00094_7rzhv_e6dfe870-c2a2-4566-9f4a-52b8fdc6491e.gz (240/264)
# Processing 20240126_122714_00094_7rzhv_e76d5255-1b50-432f-91af-ca5972e55481.gz (241/264)
# Processing 20240126_122714_00094_7rzhv_e80d7fc5-e936-4d36-b861-354c7776bbb2.gz (242/264)
# Processing 20240126_122714_00094_7rzhv_e83ccf5d-1919-4ce6-9fec-177494bc802e.gz (243/264)
# Processing 20240126_122714_00094_7rzhv_e866573b-0477-4dc7-a876-00278d58de16.gz (244/264)
# Processing 20240126_122714_00094_7rzhv_e95a95bf-2a89-4870-bc17-d38c29c81948.gz (245/264)
# Processing 20240126_122714_00094_7rzhv_ea72c294-49d8-47aa-85b6-cf2972ecb8d5.gz (246/264)
# Processing 20240126_122714_00094_7rzhv_ea8a94a0-3d76-4e1e-b5f8-d7a94c4ac3ae.gz (247/264)
# Processing 20240126_122714_00094_7rzhv_eab22a82-e340-4ac4-8c36-0226df8cd616.gz (248/264)
# Processing 20240126_122714_00094_7rzhv_eb3510a2-8d2a-4597-bc79-2623a3046ff6.gz (249/264)
# Processing 20240126_122714_00094_7rzhv_eb9810f6-8b19-43b4-93a0-32dde7a2becd.gz (250/264)
# Processing 20240126_122714_00094_7rzhv_ef03ed54-1345-45a7-aa10-dd8cf4aaa8be.gz (251/264)
# Processing 20240126_122714_00094_7rzhv_f076272a-4768-4fb0-9e58-3f9783fb7896.gz (252/264)
# Processing 20240126_122714_00094_7rzhv_f0fc3e14-1000-4e43-b925-495ebde7ac43.gz (253/264)
# Processing 20240126_122714_00094_7rzhv_f1291370-0400-4481-bd1b-7af7c2206981.gz (254/264)
# Processing 20240126_122714_00094_7rzhv_f16fb848-8741-4923-8ed1-b9b8f6e91c00.gz (255/264)
# Processing 20240126_122714_00094_7rzhv_f30e1eec-e30f-4525-8e6c-4af8a139dfa5.gz (256/264)
# Processing 20240126_122714_00094_7rzhv_f53eeaf5-2264-440e-9e44-3a303f0c6d70.gz (257/264)
# Processing 20240126_122714_00094_7rzhv_f5c4d583-6c0a-4f70-979d-c15ab8d6b6d4.gz (258/264)
# Processing 20240126_122714_00094_7rzhv_f63662b2-3a27-4af6-8b5f-3652bc576f88.gz (259/264)
# Processing 20240126_122714_00094_7rzhv_f74a90d5-b95e-465a-ae50-6f7a5c62a80d.gz (260/264)
# Processing 20240126_122714_00094_7rzhv_f8ac2994-d75d-49cd-bc4f-b68e3d1c560a.gz (261/264)
# Processing 20240126_122714_00094_7rzhv_f92f6124-ca12-4d9f-aaa3-8cf361d96cba.gz (262/264)
# Processing 20240126_122714_00094_7rzhv_fda45955-7b90-42e8-b71d-ccad58de5444.gz (263/264)
# Processing 20240126_122714_00094_7rzhv_fe59bbfb-cb46-4b29-99b6-015c3aa52d48.gz (264/264)

# %%
#save metadata
df = pd.DataFrame(metadata)
df.to_csv('metadata.csv', index=False)

# %%
metadata
# Out:
# [{'corpusid': 111592336,
#   'externalids': {'arxiv': None,
#    'mag': '2248700607',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.17509/bs_jpbsp.v15i2.1235'},
#   'source': {'pdfurls': None,
#    'pdfsha': 'd95869434377f6aa79bb806cf2dc8d246ed4d589',
#    'oainfo': {'license': 'CCBYSA',
#     'openaccessurl': 'https://doi.org/10.17509/bs_jpbsp.v15i2.1235',
#     'status': 'GOLD'}}},
#  {'corpusid': 245117584,
#   'externalids': {'arxiv': '2112.05241',
#    'mag': None,
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': None},
#   'source': {'pdfurls': ['https://arxiv.org/pdf/2112.05241v2.pdf'],
#    'pdfsha': '34850bac56684e516e3f1830859f02473135ba9e',
#    'oainfo': None}},
#  {'corpusid': 248032628,
#   'externalids': {'arxiv': None,
#    'mag': None,
#    'acl': None,
#    'pubmed': '37435446',
#    'pubmedcentral': '10259300',
#    'dblp': None,
#    'doi': '10.1530/eo-21-0026'},
#   'source': {'pdfurls': ['https://eo.bioscientifica.com/downloadpdf/journals/eo/2/1/EO-21-0026.pdf'],
#    'pdfsha': '466e3ebbad20362dd097d85a71284374da4cc171',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://eo.bioscientifica.com/downloadpdf/journals/eo/2/1/EO-21-0026.pdf',
#     'status': 'GOLD'}}},
#  {'corpusid': 230798138,
#   'externalids': {'arxiv': None,
#    'mag': '3112721540',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.33696/orthopaedics.1.015'},
#   'source': {'pdfurls': ['https://www.scientificarchives.com/admin/assets/articles/pdf/hamstrings-injuries-with-mri-findings-in-a-major-league-soccer-team-20201208041251.pdf'],
#    'pdfsha': 'b68b9db000c9fe27c88160ef881e100fe7fbb70c',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://www.scientificarchives.com/admin/assets/articles/pdf/hamstrings-injuries-with-mri-findings-in-a-major-league-soccer-team-20201208041251.pdf',
#     'status': 'HYBRID'}}},
#  {'corpusid': 220045336,
#   'externalids': {'arxiv': None,
#    'mag': '3036020225',
#    'acl': None,
#    'pubmed': '32575869',
#    'pubmedcentral': '7356165',
#    'dblp': None,
#    'doi': '10.3390/jcm9061940'},
#   'source': {'pdfurls': None, 'pdfsha': None, 'oainfo': None}},
#  {'corpusid': 222148635,
#   'externalids': {'arxiv': None,
#    'mag': '3091761504',
#    'acl': None,
#    'pubmed': '33003422',
#    'pubmedcentral': '7582773',
#    'dblp': 'journals/sensors/MateoPJ20',
#    'doi': '10.3390/s20195582'},
#   'source': {'pdfurls': None,
#    'pdfsha': '4bb0799fbbef37af2a83939e92d40e5ab8db8a8c',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://www.mdpi.com/1424-8220/20/19/5582/pdf',
#     'status': 'GOLD'}}},
#  {'corpusid': 84537732,
#   'externalids': {'arxiv': None,
#    'mag': '2014654326',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1590/s0102-05362011000300009'},
#   'source': {'pdfurls': ['http://www.abhorticultura.com.br/Revista/Revista_29_3/PE_2223.pdf'],
#    'pdfsha': '4e3523b6f0961c155a3c12920fe6ddde8a8aafb0',
#    'oainfo': {'license': 'CCBYNC',
#     'openaccessurl': 'https://www.scielo.br/j/hb/a/cMyq739jMfKSFtskBV9mWcL/?format=pdf&lang=pt',
#     'status': 'GOLD'}}},
#  {'corpusid': 84539215,
#   'externalids': {'arxiv': None,
#    'mag': '2009907618',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1590/s0103-84782013001100013'},
#   'source': {'pdfurls': ['http://www.scielo.br/pdf/cr/v43n11/a30713cr2012-1167.pdf'],
#    'pdfsha': 'ff037162e165fde4796338d3f8fc7d2c48924b5a',
#    'oainfo': {'license': 'CCBYNC',
#     'openaccessurl': 'https://www.scielo.br/j/cr/a/tNdwGM8Rbx7fQ4nnwqYgXyD/?format=pdf&lang=en',
#     'status': 'GOLD'}}},
#  {'corpusid': 84539758,
#   'externalids': {'arxiv': None,
#    'mag': '2024193823',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1590/s0100-41582001000300018'},
#   'source': {'pdfurls': ['http://www.scielo.br/pdf/fb/v26n3/a18v26n3.pdf'],
#    'pdfsha': '8e27930b8908170523784a2f1e2bcefad54b49b6',
#    'oainfo': {'license': 'CCBYNC',
#     'openaccessurl': 'https://www.scielo.br/j/fb/a/QT8HrpVyJWNBjt8hyNjbrZf/?format=pdf&lang=pt',
#     'status': 'GOLD'}}},
#  {'corpusid': 84542614,
#   'externalids': {'arxiv': None,
#    'mag': '2044617935',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1590/s0006-87052000000200014'},
#   'source': {'pdfurls': None,
#    'pdfsha': '0fcd700fbded4c76813d0bf6f2fb26f4537c3ee4',
#    'oainfo': {'license': 'CCBYNC',
#     'openaccessurl': 'https://www.scielo.br/j/brag/a/zgFNNsVCc8XDmTdmN7C8tQb/?format=pdf&lang=pt',
#     'status': 'GOLD'}}},
#  {'corpusid': 212856737,
#   'externalids': {'arxiv': None,
#    'mag': '2998887682',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1108/heed-09-2018-0021'},
#   'source': {'pdfurls': None,
#    'pdfsha': 'e1f07ae80d1f7bbae25194bff8770a220fba6582',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://doi.org/10.1108/heed-09-2018-0021',
#     'status': 'GOLD'}}},
#  {'corpusid': 235555207,
#   'externalids': {'arxiv': None,
#    'mag': '3157497159',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.3390/w13091134'},
#   'source': {'pdfurls': None,
#    'pdfsha': '8382ec3e2d87802c9ace56a26dac44bffcc97c60',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://www.mdpi.com/2073-4441/13/9/1134/pdf',
#     'status': 'GOLD'}}},
#  {'corpusid': 195825126,
#   'externalids': {'arxiv': None,
#    'mag': '2962038144',
#    'acl': None,
#    'pubmed': '31338102',
#    'pubmedcentral': '6629910',
#    'dblp': None,
#    'doi': '10.3389/fpls.2019.00875'},
#   'source': {'pdfurls': None,
#    'pdfsha': 'fc0c41095b7b046fcb67c22b3d054e457682148e',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://www.frontiersin.org/articles/10.3389/fpls.2019.00875/pdf',
#     'status': 'GOLD'}}},
#  {'corpusid': 54048048,
#   'externalids': {'arxiv': None,
#    'mag': '2114615581',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.4236/ojn.2013.36059'},
#   'source': {'pdfurls': None,
#    'pdfsha': '4956cb21cc996ae160a278993128682f247da5cf',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'http://www.scirp.org/journal/PaperDownload.aspx?paperID=38497',
#     'status': 'GOLD'}}},
#  {'corpusid': 59053824,
#   'externalids': {'arxiv': None,
#    'mag': '2606666593',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.4172/2161-1459.1000200'},
#   'source': {'pdfurls': None,
#    'pdfsha': '002086d9c713941cd8ec9ccbfa2a2571c7782cd1',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://www.omicsonline.org/open-access/model-based-description-of-the-pharmacokinetic-behavior-of-pentobarbitalin-fasted-male-volunteers-after-oral-administration-of-10-2161-1459-1000200.pdf',
#     'status': 'HYBRID'}}},
#  {'corpusid': 55845260,
#   'externalids': {'arxiv': None,
#    'mag': '2325454514',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.4067/s0717-92002014000300009'},
#   'source': {'pdfurls': ['https://scielo.conicyt.cl/pdf/bosque/v35n3/art09.pdf'],
#    'pdfsha': '3ae3f597b66768dfd1d935a12c9a5543155cbe16',
#    'oainfo': {'license': 'CCBYNC',
#     'openaccessurl': 'http://www.scielo.cl/pdf/bosque/v35n3/art09.pdf',
#     'status': 'GOLD'}}},
#  {'corpusid': 55846618,
#   'externalids': {'arxiv': None,
#    'mag': '2072674833',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1155/2012/352937'},
#   'source': {'pdfurls': ['http://downloads.hindawi.com/journals/jnm/2012/352937.pdf'],
#    'pdfsha': '423fe235348a215feab1692f3252fd5ee41001f3',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://downloads.hindawi.com/journals/jnm/2012/352937.pdf',
#     'status': 'GOLD'}}},
#  {'corpusid': 119393757,
#   'externalids': {'arxiv': '1708.03336',
#    'mag': '3103197186',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1051/0004-6361/201731581'},
#   'source': {'pdfurls': ['https://arxiv.org/pdf/1708.03336v2.pdf'],
#    'pdfsha': '7193dad14f80714974e51f0c7ac8cab987abbc72',
#    'oainfo': {'license': None,
#     'openaccessurl': 'https://www.aanda.org/articles/aa/pdf/2017/09/aa31581-17.pdf',
#     'status': 'BRONZE'}}},
#  {'corpusid': 101073400,
#   'externalids': {'arxiv': '1602.08870',
#    'mag': '3105549618',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1016/j.cocis.2016.03.004'},
#   'source': {'pdfurls': ['https://arxiv.org/pdf/1602.08870v2.pdf'],
#    'pdfsha': '4eb6b9ffaed427f8109126b5fb3a179d6099fa43',
#    'oainfo': {'license': None,
#     'openaccessurl': 'http://arxiv.org/pdf/1602.08870',
#     'status': 'GREEN'}}},
#  {'corpusid': 233658345,
#   'externalids': {'arxiv': None,
#    'mag': '3139389011',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.3390/math9060645'},
#   'source': {'pdfurls': None,
#    'pdfsha': 'ba4ff00412fd1741ae36702f9918bf2e1264d572',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://www.mdpi.com/2227-7390/9/6/645/pdf',
#     'status': 'GOLD'}}},
#  {'corpusid': 214267707,
#   'externalids': {'arxiv': None,
#    'mag': '2997550559',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1088/1757-899x/709/2/022041'},
#   'source': {'pdfurls': ['https://web.archive.org/web/20200104014112/https:/iopscience.iop.org/article/10.1088/1757-899X/709/2/022041/pdf'],
#    'pdfsha': '310b2c91858f003e9c8e23bff5842460e96bde06',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://doi.org/10.1088/1757-899x/709/2/022041',
#     'status': 'GOLD'}}},
#  {'corpusid': 256613011,
#   'externalids': {'arxiv': None,
#    'mag': None,
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1038/s41419-020-2664-0'},
#   'source': {'pdfurls': None,
#    'pdfsha': 'c5775b3de8d0b37b94c6bb32a9fcc72540c7752c',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://www.nature.com/articles/s41419-020-2664-0.pdf',
#     'status': 'GOLD'}}},
#  {'corpusid': 91186206,
#   'externalids': {'arxiv': None,
#    'mag': '2899484859',
#    'acl': None,
#    'pubmed': '30961140',
#    'pubmedcentral': '6290609',
#    'dblp': None,
#    'doi': '10.3390/polym10111215'},
#   'source': {'pdfurls': None,
#    'pdfsha': 'd72a747909680a6a489b354d02fa6494908e3d08',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://www.mdpi.com/2073-4360/10/11/1215/pdf',
#     'status': 'GOLD'}}},
#  {'corpusid': 225178763,
#   'externalids': {'arxiv': None,
#    'mag': '3047510940',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.19113/sdufenbed.651622'},
#   'source': {'pdfurls': ['https://web.archive.org/web/20200819195630/https:/dergipark.org.tr/tr/download/article-file/863388'],
#    'pdfsha': '26e54a7a83e0fce9845ce4a3612b6f90530b59c0',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://dergipark.org.tr/tr/download/article-file/863388',
#     'status': 'GOLD'}}},
#  {'corpusid': 229479414,
#   'externalids': {'arxiv': None,
#    'mag': '3110485541',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.4236/ojml.2020.106044'},
#   'source': {'pdfurls': ['https://www.scirp.org/pdf/ojml_2020112413425867.pdf'],
#    'pdfsha': 'ae87f1b73eef7c03f9998a852112c20c60985dde',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'http://www.scirp.org/journal/PaperDownload.aspx?paperID=104326',
#     'status': 'GOLD'}}},
#  {'corpusid': 260808749,
#   'externalids': {'arxiv': None,
#    'mag': None,
#    'acl': None,
#    'pubmed': '37609256',
#    'pubmedcentral': '10441406',
#    'dblp': None,
#    'doi': '10.1101/2023.08.08.552509'},
#   'source': {'pdfurls': None,
#    'pdfsha': '1ca31f9d717afe971011c19979f77a9b5197ee53',
#    'oainfo': {'license': 'CCBYNCND',
#     'openaccessurl': 'https://www.biorxiv.org/content/biorxiv/early/2023/08/09/2023.08.08.552509.1.full.pdf',
#     'status': 'GREEN'}}},
#  {'corpusid': 236530020,
#   'externalids': {'arxiv': None,
#    'mag': None,
#    'acl': None,
#    'pubmed': '34345198',
#    'pubmedcentral': '8321508',
#    'dblp': 'journals/mta/NarayananKSTJRK22',
#    'doi': '10.1007/s11042-021-11264-6'},
#   'source': {'pdfurls': None,
#    'pdfsha': '377d8a72d31055332463c4db87a62766009b1f8f',
#    'oainfo': {'license': None,
#     'openaccessurl': 'https://link.springer.com/content/pdf/10.1007/s11042-021-11264-6.pdf',
#     'status': 'BRONZE'}}},
#  {'corpusid': 233908734,
#   'externalids': {'arxiv': None,
#    'mag': '3128215739',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.5194/acp-21-1797-2021'},
#   'source': {'pdfurls': ['https://acp.copernicus.org/articles/21/1797/2021/acp-21-1797-2021.pdf'],
#    'pdfsha': 'dd196d3dbb1263dc6f50ca98910d763fb1684d01',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://acp.copernicus.org/articles/21/1797/2021/acp-21-1797-2021.pdf',
#     'status': 'GOLD'}}},
#  {'corpusid': 233569851,
#   'externalids': {'arxiv': None,
#    'mag': '3140985760',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1155/2021/5548785'},
#   'source': {'pdfurls': None,
#    'pdfsha': 'f324ddedc308215c4347e4805e64d3830669cdfb',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://doi.org/10.1155/2021/5548785',
#     'status': 'GOLD'}}},
#  {'corpusid': 243994784,
#   'externalids': {'arxiv': None,
#    'mag': None,
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.52420/2071-5943-2021-20-4-85-92'},
#   'source': {'pdfurls': None,
#    'pdfsha': '74e17efd3fdcec102fc09b188be83c17cfd69cd0',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://umj.usma.ru/jour/article/download/824/802',
#     'status': 'HYBRID'}}},
#  {'corpusid': 243995069,
#   'externalids': {'arxiv': None,
#    'mag': None,
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1051/e3sconf/202132300022'},
#   'source': {'pdfurls': ['https://www.e3s-conferences.org/articles/e3sconf/pdf/2021/99/e3sconf_mpsu2021_00022.pdf'],
#    'pdfsha': '4918cc4f1a2d5ffc60197dfe3d8c099ab8be04b2',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://www.e3s-conferences.org/articles/e3sconf/pdf/2021/99/e3sconf_mpsu2021_00022.pdf',
#     'status': 'GOLD'}}},
#  {'corpusid': 226289679,
#   'externalids': {'arxiv': '2011.05275',
#    'mag': '3103153621',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': 'journals/corr/abs-2011-05275',
#    'doi': None},
#   'source': {'pdfurls': ['https://arxiv.org/pdf/2011.05275v1.pdf'],
#    'pdfsha': '5a09023646090bb79c61a657c41db6dcd267df6a',
#    'oainfo': None}},
#  {'corpusid': 230524057,
#   'externalids': {'arxiv': '2101.01447',
#    'mag': '3127165192',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': 'journals/tcsv/SuCSWCCCH21',
#    'doi': '10.1109/tcsvt.2021.3051277'},
#   'source': {'pdfurls': ['https://arxiv.org/pdf/2101.01447v1.pdf'],
#    'pdfsha': 'fc3a37ddb5019ce2630753a09f56888fcbbd8cdc',
#    'oainfo': {'license': None,
#     'openaccessurl': 'http://arxiv.org/pdf/2101.01447',
#     'status': 'GREEN'}}},
#  {'corpusid': 230524539,
#   'externalids': {'arxiv': None,
#    'mag': '3112109369',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.5751/es-11977-250434'},
#   'source': {'pdfurls': ['https://www.ecologyandsociety.org/vol25/iss4/art34/ES-2020-11977.pdf'],
#    'pdfsha': '8b0ad1bcfa9f75c7c0ccb33fbd5bcfdbabe78754',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'http://www.ecologyandsociety.org/vol25/iss4/art34/ES-2020-11977.pdf',
#     'status': 'GOLD'}}},
#  {'corpusid': 119160400,
#   'externalids': {'arxiv': '1505.03058',
#    'mag': '2950005960',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1088/1748-0221/11/02/c02037'},
#   'source': {'pdfurls': ['https://arxiv.org/pdf/1505.03058v1.pdf'],
#    'pdfsha': 'a3e169772f2587066f4a19a0205523713d816f6b',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://doi.org/10.1088/1748-0221/11/02/c02037',
#     'status': 'HYBRID'}}},
#  {'corpusid': 221038722,
#   'externalids': {'arxiv': None,
#    'mag': '3047890849',
#    'acl': None,
#    'pubmed': '32761079',
#    'pubmedcentral': '7758032',
#    'dblp': None,
#    'doi': '10.1093/pcp/pcaa104'},
#   'source': {'pdfurls': None,
#    'pdfsha': '7b6f4706b6a1bffecf887848d9173f42021026fa',
#    'oainfo': {'license': 'CCBYNC',
#     'openaccessurl': 'https://academic.oup.com/pcp/article-pdf/61/11/1902/36205131/pcaa104.pdf',
#     'status': 'HYBRID'}}},
#  {'corpusid': 221069254,
#   'externalids': {'arxiv': None,
#    'mag': '3048416463',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.7324/japs.2020.10803'},
#   'source': {'pdfurls': ['https://www.japsonline.com/admin/php/uploads/3185_pdf.pdf'],
#    'pdfsha': 'b13155d354456971326a1f7954011d3f4d3eb43f',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://www.japsonline.com/admin/php/uploads/3185_pdf.pdf',
#     'status': 'GOLD'}}},
#  {'corpusid': 201251168,
#   'externalids': {'arxiv': None,
#    'mag': '2967466257',
#    'acl': None,
#    'pubmed': '31448092',
#    'pubmedcentral': '6694448',
#    'dblp': None,
#    'doi': '10.12688/f1000research.19610.1'},
#   'source': {'pdfurls': None,
#    'pdfsha': 'e61ea76dfecde597bfad258589026442f360a17f',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://f1000research.com/articles/8-1403/v1/pdf',
#     'status': 'GOLD'}}},
#  {'corpusid': 229529899,
#   'externalids': {'arxiv': None,
#    'mag': '3106731445',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.34096/cas.i52.7469'},
#   'source': {'pdfurls': ['http://revistascientificas.filo.uba.ar/index.php/CAS/article/download/7469/7719'],
#    'pdfsha': '61b96788e1651139812c82630a416b800cbc88a9',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'http://revistascientificas.filo.uba.ar/index.php/CAS/article/download/7469/7719',
#     'status': 'GOLD'}}},
#  {'corpusid': 212457624,
#   'externalids': {'arxiv': None,
#    'mag': None,
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.29121/granthaalayah.v5.i6.2017.2098'},
#   'source': {'pdfurls': None,
#    'pdfsha': '53fa7c068f6efd5b650374120922a1d638485f10',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://www.granthaalayahpublication.org/journals/index.php/granthaalayah/article/download/IJRG17_A06_449/1979',
#     'status': 'HYBRID'}}},
#  {'corpusid': 202669948,
#   'externalids': {'arxiv': None,
#    'mag': '2973149592',
#    'acl': None,
#    'pubmed': '31534529',
#    'pubmedcentral': '6735372',
#    'dblp': None,
#    'doi': '10.7150/thno.36320'},
#   'source': {'pdfurls': None,
#    'pdfsha': 'f9bdf958bde8d8217c076873dd6010a53ee11098',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://doi.org/10.7150/thno.36320',
#     'status': 'GOLD'}}},
#  {'corpusid': 213480338,
#   'externalids': {'arxiv': None,
#    'mag': '3000710203',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.3390/app10020648'},
#   'source': {'pdfurls': ['https://web.archive.org/web/20200215100833/https:/res.mdpi.com/d_attachment/applsci/applsci-10-00648/article_deploy/applsci-10-00648-v2.pdf'],
#    'pdfsha': '5b24082bcefdf7fe6f28247487f6c9a5d537c471',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://www.mdpi.com/2076-3417/10/2/648/pdf',
#     'status': 'GOLD'}}},
#  {'corpusid': 19121152,
#   'externalids': {'arxiv': None,
#    'mag': '2417081575',
#    'acl': None,
#    'pubmed': '27375387',
#    'pubmedcentral': '4916816',
#    'dblp': None,
#    'doi': '10.4103/1658-354x.174922'},
#   'source': {'pdfurls': ['https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4916816/pdf/'],
#    'pdfsha': '56824d3300930139d4aff31e93ac97222a905966',
#    'oainfo': {'license': 'CCBYNCSA',
#     'openaccessurl': 'https://doi.org/10.4103/1658-354x.174922',
#     'status': 'GOLD'}}},
#  {'corpusid': 248798987,
#   'externalids': {'arxiv': None,
#    'mag': None,
#    'acl': None,
#    'pubmed': '35573712',
#    'pubmedcentral': '9078060',
#    'dblp': None,
#    'doi': '10.22037/aaem.v10i1.1543'},
#   'source': {'pdfurls': None,
#    'pdfsha': 'dece419ed96c8dc378623c5f31a00d6597722187',
#    'oainfo': {'license': 'CCBY', 'openaccessurl': None, 'status': None}}},
#  {'corpusid': 202661180,
#   'externalids': {'arxiv': '1909.08270',
#    'mag': '3047462383',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1090/tran/8252'},
#   'source': {'pdfurls': ['https://arxiv.org/pdf/1909.08270v1.pdf'],
#    'pdfsha': '0ecef6dfb5a3db1d06e5096802a2a513eee10724',
#    'oainfo': {'license': 'publisher-specific, author manuscript',
#     'openaccessurl': 'https://doi.org/10.1090/tran/8252',
#     'status': 'HYBRID'}}},
#  {'corpusid': 102488940,
#   'externalids': {'arxiv': '0912.1613',
#    'mag': '2064109159',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1143/ptp.123.449'},
#   'source': {'pdfurls': ['https://arxiv.org/pdf/0912.1613v2.pdf'],
#    'pdfsha': '73061de011080ad3dca57e571ae37cff52597d6e',
#    'oainfo': {'license': None,
#     'openaccessurl': 'http://arxiv.org/pdf/0912.1613',
#     'status': 'GREEN'}}},
#  {'corpusid': 43344777,
#   'externalids': {'arxiv': '1307.0288',
#    'mag': '2028358635',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': 'journals/cphysics/FanUSH14',
#    'doi': '10.1016/j.cpc.2013.08.009'},
#   'source': {'pdfurls': ['https://arxiv.org/pdf/1307.0288v1.pdf'],
#    'pdfsha': '56b88ce6b6b0066cadf7da548030c6ffce2c6444',
#    'oainfo': {'license': None,
#     'openaccessurl': 'http://arxiv.org/pdf/1307.0288',
#     'status': 'GREEN'}}},
#  {'corpusid': 226289346,
#   'externalids': {'arxiv': None,
#    'mag': '3093820916',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.5539/ies.v13n11p55'},
#   'source': {'pdfurls': None,
#    'pdfsha': '3dff7444bb66f2c9aadaee72fb0e5f622d319862',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://www.ccsenet.org/journal/index.php/ies/article/download/0/0/44003/46502',
#     'status': 'GOLD'}}},
#  {'corpusid': 245334914,
#   'externalids': {'arxiv': '2112.10759',
#    'mag': None,
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': 'conf/cvpr/XuPYSZ22',
#    'doi': '10.1109/cvpr52688.2022.01788'},
#   'source': {'pdfurls': ['https://arxiv.org/pdf/2112.10759v2.pdf'],
#    'pdfsha': '117b816ebd036b2fa008b4f1371dd607f881c150',
#    'oainfo': None}},
#  {'corpusid': 54713501,
#   'externalids': {'arxiv': '1102.1593',
#    'mag': '1641181289',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1063/1.3599886'},
#   'source': {'pdfurls': ['https://arxiv.org/pdf/1102.1593v1.pdf'],
#    'pdfsha': 'cec0c4110f0a9393e9746160eb74a5b541d822dc',
#    'oainfo': {'license': 'CCBYNCND',
#     'openaccessurl': 'https://riunet.upv.es/bitstream/10251/57766/1/Romero;S%C3%A1nchez;Garc%C3%ADa-Raffi%20-%20Tunable%20wideband%20bandstop%20acoustic%20filter%20based%20on%20two-dimensional%20....pdf',
#     'status': 'GREEN'}}},
#  {'corpusid': 88517022,
#   'externalids': {'arxiv': '1608.05122',
#    'mag': '3104039207',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.15559/16-vmsta67'},
#   'source': {'pdfurls': ['https://arxiv.org/pdf/1608.05122v3.pdf'],
#    'pdfsha': '2954dbec5f84991c082d4062fff15b6c26dfbdbb',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://www.vmsta.org/journal/VMSTA/article/75/file/pdf',
#     'status': 'GOLD'}}},
#  {'corpusid': 2717015,
#   'externalids': {'arxiv': None,
#    'mag': '2165422354',
#    'acl': None,
#    'pubmed': '21097508',
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1074/jbc.m110.189308'},
#   'source': {'pdfurls': None,
#    'pdfsha': '8363d2f72e44d12fd5788e1629c439affd437728',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'http://www.jbc.org/content/286/3/1938.full.pdf',
#     'status': 'HYBRID'}}},
#  {'corpusid': 95480485,
#   'externalids': {'arxiv': None,
#    'mag': '2003739011',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.4025/actascitechnol.v26i2.1513'},
#   'source': {'pdfurls': ['http://periodicos.uem.br/ojs/index.php/ActaSciTechnol/article/download/1513/871'],
#    'pdfsha': '749f408a7becf64d2dc812d679e4680627a43d55',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://periodicos.uem.br/ojs/index.php/ActaSciTechnol/article/download/1513/871',
#     'status': 'GOLD'}}},
#  {'corpusid': 219670546,
#   'externalids': {'arxiv': None,
#    'mag': '3018728857',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.33448/rsd-v9i6.3520'},
#   'source': {'pdfurls': ['https://rsdjournal.org/index.php/rsd/article/download/3520/3824'],
#    'pdfsha': '32b6a27b80acf76669de0ca7572b5dd0fae1feed',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://rsdjournal.org/index.php/rsd/article/download/3520/3824',
#     'status': 'GOLD'}}},
#  {'corpusid': 229528607,
#   'externalids': {'arxiv': None,
#    'mag': '3109713858',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.47747/jpsii.v1i1.64'},
#   'source': {'pdfurls': ['http://journal.jis-institute.org/index.php/jpsii/article/download/64/41'],
#    'pdfsha': '98808b9b63c65b96a1c4f39951d0522e3d454c9d',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'http://journal.jis-institute.org/index.php/jpsii/article/download/64/41',
#     'status': 'GOLD'}}},
#  {'corpusid': 229529367,
#   'externalids': {'arxiv': None,
#    'mag': '3110414034',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1590/1983-21252020v33n410rc'},
#   'source': {'pdfurls': None,
#    'pdfsha': 'b05720fe3e2e8655806a58b4d1ba4ff34e66cd24',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'http://www.scielo.br/j/rcaat/a/h7KPfzfKJbnQFgj7HLFzppq/?format=pdf&lang=en',
#     'status': 'GOLD'}}},
#  {'corpusid': 251006410,
#   'externalids': {'arxiv': None,
#    'mag': None,
#    'acl': None,
#    'pubmed': '35894388',
#    'pubmedcentral': '9311270',
#    'dblp': None,
#    'doi': '10.1590/1678-7757-2022-0161'},
#   'source': {'pdfurls': None,
#    'pdfsha': '07829a590c7bb2616273c4f4c5f94c25dd3802e5',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://www.scielo.br/j/jaos/a/gC8MwWgwFsPcNBcFH9zg6Cj/?format=pdf&lang=en',
#     'status': 'GOLD'}}},
#  {'corpusid': 84643617,
#   'externalids': {'arxiv': None,
#    'mag': '2011865728',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1590/s1413-70542003000300015'},
#   'source': {'pdfurls': ['http://www.scielo.br/pdf/cagro/v27n3/a15v27n3.pdf'],
#    'pdfsha': 'ffdb386b448fac5a07510772e9490ed3d5cfbcf8',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://www.scielo.br/j/cagro/a/cRXvdhjN7PNbGdj8QCRncyk/?format=pdf&lang=pt',
#     'status': 'GOLD'}}},
#  {'corpusid': 103298471,
#   'externalids': {'arxiv': None,
#    'mag': '2790706520',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1051/e3sconf/20183402022'},
#   'source': {'pdfurls': ['https://web.archive.org/web/20180719100538/https:/www.e3s-conferences.org/articles/e3sconf/pdf/2018/09/e3sconf_cenviron2018_02022.pdf'],
#    'pdfsha': '3ff5652ea74cb2396cc73fca1f2dddfa22dfc682',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://www.e3s-conferences.org/articles/e3sconf/pdf/2018/09/e3sconf_cenviron2018_02022.pdf',
#     'status': 'GOLD'}}},
#  {'corpusid': 103312685,
#   'externalids': {'arxiv': None,
#    'mag': '2774928301',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.24820/ark.5550190.p010.163'},
#   'source': {'pdfurls': ['https://www.arkat-usa.org/get-file/61689/'],
#    'pdfsha': '6c412b14f3d38b73b37f259a00d67208939d4343',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://www.arkat-usa.org/get-file/61689/',
#     'status': 'GOLD'}}},
#  {'corpusid': 1335358,
#   'externalids': {'arxiv': '1302.1024',
#    'mag': '2160787509',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1088/0951-7715/26/11/2951'},
#   'source': {'pdfurls': ['https://arxiv.org/pdf/1302.1024v1.pdf'],
#    'pdfsha': '13464474943ba2f293ad8ba93a59bba37a668353',
#    'oainfo': {'license': None,
#     'openaccessurl': 'https://purehost.bath.ac.uk/ws/files/18705420/Zimmer_2013_Nonlinearity.pdf',
#     'status': 'GREEN'}}},
#  {'corpusid': 43427914,
#   'externalids': {'arxiv': '1305.0827',
#    'mag': '2003609563',
#    'acl': None,
#    'pubmed': '24266480',
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1103/physrevlett.111.196601'},
#   'source': {'pdfurls': ['https://arxiv.org/pdf/1305.0827v1.pdf'],
#    'pdfsha': 'c8cd14bcf502851ad12ba681577571b2d92faf1f',
#    'oainfo': {'license': None,
#     'openaccessurl': 'http://arxiv.org/pdf/1305.0827',
#     'status': 'GREEN'}}},
#  {'corpusid': 219539699,
#   'externalids': {'arxiv': None,
#    'mag': '3033299895',
#    'acl': None,
#    'pubmed': '32507773',
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1507/endocrj.ej20-0149'},
#   'source': {'pdfurls': ['https://web.archive.org/web/20201209164603/https:/www.jstage.jst.go.jp/article/endocrj/67/9/67_EJ20-0149/_pdf'],
#    'pdfsha': '27ab1e5ca92d50fdca0d04673878c837458f779b',
#    'oainfo': {'license': None,
#     'openaccessurl': 'https://www.jstage.jst.go.jp/article/endocrj/67/9/67_EJ20-0149/_pdf',
#     'status': 'GOLD'}}},
#  {'corpusid': 212416246,
#   'externalids': {'arxiv': None,
#    'mag': '3006048214',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.21122/1683-6065-2019-4-72-75'},
#   'source': {'pdfurls': ['https://lim.bntu.by/jour/article/viewFile/3155/3077'],
#    'pdfsha': 'fab46f0785d6b7fae6a2ba9c45dc7b525cc5642e',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://lim.bntu.by/jour/article/download/3155/3077',
#     'status': 'GOLD'}}},
#  {'corpusid': 212416467,
#   'externalids': {'arxiv': None,
#    'mag': '3007974247',
#    'acl': None,
#    'pubmed': '32131045',
#    'pubmedcentral': '7175184',
#    'dblp': None,
#    'doi': '10.2196/15819'},
#   'source': {'pdfurls': ['https://www.jmir.org/2020/4/e15819/PDF'],
#    'pdfsha': 'c52caa724805afc9d80a5c56f0508cd6d73c94d9',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://www.jmir.org/2020/4/e15819/PDF',
#     'status': 'GOLD'}}},
#  {'corpusid': 212416531,
#   'externalids': {'arxiv': None,
#    'mag': '3010313411',
#    'acl': None,
#    'pubmed': '32133530',
#    'pubmedcentral': '7056950',
#    'dblp': None,
#    'doi': '10.1093/ndt/gfz288'},
#   'source': {'pdfurls': None,
#    'pdfsha': '73496b6fc1cd5fcd2506203aeeec1da57178e39f',
#    'oainfo': {'license': 'CCBYNC',
#     'openaccessurl': 'https://academic.oup.com/ndt/article-pdf/35/3/512/34305497/gfz288.pdf',
#     'status': 'HYBRID'}}},
#  {'corpusid': 212416643,
#   'externalids': {'arxiv': None,
#    'mag': '3007278725',
#    'acl': None,
#    'pubmed': '32130288',
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1590/1519-6984.228874'},
#   'source': {'pdfurls': ['http://www.scielo.br/pdf/bjb/v81n1/1519-6984-bjb-1519-6984228874.pdf'],
#    'pdfsha': '805ffb435c4312d8cf027616bd28185898e1ddf3',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'http://www.scielo.br/j/bjb/a/B7KjwvvwTgFVMDZD8RtXJ6F/?format=pdf&lang=en',
#     'status': 'GOLD'}}},
#  {'corpusid': 4893484,
#   'externalids': {'arxiv': None,
#    'mag': '2030921993',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.5935/0103-5053.20150001'},
#   'source': {'pdfurls': None,
#    'pdfsha': '60085c3fadbb686331e38ab1e230664d58a42714',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://doi.org/10.5935/0103-5053.20150001',
#     'status': 'GOLD'}}},
#  {'corpusid': 229010093,
#   'externalids': {'arxiv': None,
#    'mag': '3106341439',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': '8705118',
#    'dblp': None,
#    'doi': '10.1177/2473011420s00055'},
#   'source': {'pdfurls': None, 'pdfsha': None, 'oainfo': None}},
#  {'corpusid': 44669622,
#   'externalids': {'arxiv': None,
#    'mag': '2011369535',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1590/s1415-47572008000200024'},
#   'source': {'pdfurls': ['http://www.scielo.br/pdf/gmb/v31n1s0/24.pdf'],
#    'pdfsha': '49b4d8f9d52f7a8bf91c33da05f925164099fd01',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://www.scielo.br/j/gmb/a/3jdqW6cpHFdtJk6znygZx8s/?format=pdf&lang=en',
#     'status': 'GOLD'}}},
#  {'corpusid': 119167402,
#   'externalids': {'arxiv': 'math/0403496',
#    'mag': '2949527042',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1007/s1474748007000023'},
#   'source': {'pdfurls': ['https://export.arxiv.org/pdf/math/0403496v2.pdf'],
#    'pdfsha': 'b1fbdbb205db06674b729350e53913c4e7642241',
#    'oainfo': None}},
#  {'corpusid': 119167537,
#   'externalids': {'arxiv': '1902.00777',
#    'mag': '3021924500',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1007/s13398-019-00747-9'},
#   'source': {'pdfurls': ['https://arxiv.org/pdf/1902.00777v2.pdf'],
#    'pdfsha': 'e416236993a184dc1be714555955dd06230eb9d3',
#    'oainfo': {'license': None,
#     'openaccessurl': 'http://arxiv.org/pdf/1902.00777',
#     'status': 'GREEN'}}},
#  {'corpusid': 230590402,
#   'externalids': {'arxiv': None,
#    'mag': '3112330013',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.36906/2311-4444/20-3/10'},
#   'source': {'pdfurls': ['https://vestnik.nvsu.ru/2311-1402/article/download/49724/pdf'],
#    'pdfsha': '901b52ed2cb3371159c181f9e6a715f3396a0dc3',
#    'oainfo': {'license': None,
#     'openaccessurl': 'https://vestnik.nvsu.ru/2311-1402/article/download/49724/pdf',
#     'status': 'GOLD'}}},
#  {'corpusid': 211568575,
#   'externalids': {'arxiv': None,
#    'mag': None,
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.18520/cs/v118/i3/444-448'},
#   'source': {'pdfurls': None,
#    'pdfsha': '350e07e170eaf74c7912d2f5711477201ccb5da2',
#    'oainfo': {'license': None,
#     'openaccessurl': 'https://doi.org/10.18520/cs/v118/i3/444-448',
#     'status': 'GOLD'}}},
#  {'corpusid': 52337154,
#   'externalids': {'arxiv': None,
#    'mag': '2890960514',
#    'acl': None,
#    'pubmed': '30244766',
#    'pubmedcentral': '6148050',
#    'dblp': None,
#    'doi': '10.1016/j.jaim.2018.08.005'},
#   'source': {'pdfurls': None,
#    'pdfsha': '0258ef696a182e4c619df554bfc6ce0505bae20e',
#    'oainfo': {'license': 'CCBYNCND',
#     'openaccessurl': 'https://doi.org/10.1016/j.jaim.2018.08.005',
#     'status': 'GOLD'}}},
#  {'corpusid': 78942522,
#   'externalids': {'arxiv': None,
#    'mag': '2588290203',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.21109/kesmas.v11i3.1147'},
#   'source': {'pdfurls': None,
#    'pdfsha': 'fce43b36045ee2bb0ab4b32272e270e2814ad1b8',
#    'oainfo': {'license': 'CCBYSA',
#     'openaccessurl': 'http://journal.fkm.ui.ac.id/kesmas/article/download/1147/540',
#     'status': 'GOLD'}}},
#  {'corpusid': 235451275,
#   'externalids': {'arxiv': None,
#    'mag': None,
#    'acl': None,
#    'pubmed': '34131984',
#    'pubmedcentral': '8410671',
#    'dblp': None,
#    'doi': '10.1002/chem.202101421'},
#   'source': {'pdfurls': None,
#    'pdfsha': '73bd1e7e1abeff2942ee42b0176d2b30a39b048d',
#    'oainfo': {'license': 'CCBYNCND',
#     'openaccessurl': 'https://onlinelibrary.wiley.com/doi/pdfdirect/10.1002/chem.202101421',
#     'status': 'HYBRID'}}},
#  {'corpusid': 210926410,
#   'externalids': {'arxiv': None,
#    'mag': '3002088299',
#    'acl': None,
#    'pubmed': '31988483',
#    'pubmedcentral': '7062630',
#    'dblp': None,
#    'doi': '10.1038/s41430-020-0570-2'},
#   'source': {'pdfurls': None,
#    'pdfsha': '49e3f8472b87d773a7740828a6b0fa5e7006abf8',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://www.nature.com/articles/s41430-020-0570-2.pdf',
#     'status': 'HYBRID'}}},
#  {'corpusid': 17175868,
#   'externalids': {'arxiv': 'math/0409387',
#    'mag': '2951830210',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1007/bf02972666'},
#   'source': {'pdfurls': ['https://arxiv.org/pdf/math/0409387v1.pdf'],
#    'pdfsha': '33b274352fb59e244c71b50d1dabd33d0d4e10e5',
#    'oainfo': {'license': None,
#     'openaccessurl': 'http://arxiv.org/pdf/math/0409387v1.pdf',
#     'status': 'GREEN'}}},
#  {'corpusid': 245876927,
#   'externalids': {'arxiv': None,
#    'mag': None,
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1088/1742-6596/2152/1/012051'},
#   'source': {'pdfurls': None,
#    'pdfsha': '26ab4e1b24140077b04960962b629569800af60b',
#    'oainfo': {'license': None,
#     'openaccessurl': 'https://doi.org/10.1088/1742-6596/2152/1/012051',
#     'status': 'GOLD'}}},
#  {'corpusid': 6151259,
#   'externalids': {'arxiv': None,
#    'mag': '1995097856',
#    'acl': None,
#    'pubmed': '23714352',
#    'pubmedcentral': '3672018',
#    'dblp': None,
#    'doi': '10.1186/1471-2458-13-515'},
#   'source': {'pdfurls': None,
#    'pdfsha': '80a9cdff4efebc4aa6b7aa51f6b56a46be471333',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://bmcpublichealth.biomedcentral.com/track/pdf/10.1186/1471-2458-13-515',
#     'status': 'GOLD'}}},
#  {'corpusid': 194121373,
#   'externalids': {'arxiv': None,
#    'mag': '2155493356',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.22456/2236-6385.24948'},
#   'source': {'pdfurls': ['https://seer.ufrgs.br/cadernosdoil/article/download/24948/15025'],
#    'pdfsha': 'a9cbb1db1f2ff4ef780b8ca2db324f4207d737d0',
#    'oainfo': {'license': None,
#     'openaccessurl': 'https://seer.ufrgs.br/cadernosdoil/article/download/24948/15025',
#     'status': 'GOLD'}}},
#  {'corpusid': 257282868,
#   'externalids': {'arxiv': None,
#    'mag': None,
#    'acl': None,
#    'pubmed': '36859777',
#    'pubmedcentral': '10236607',
#    'dblp': None,
#    'doi': '10.1111/cas.15762'},
#   'source': {'pdfurls': None,
#    'pdfsha': '65979a1aa98693bc3727687a4c6e2de22c28b913',
#    'oainfo': {'license': 'CCBYNCND',
#     'openaccessurl': 'https://onlinelibrary.wiley.com/doi/pdfdirect/10.1111/cas.15762',
#     'status': 'GOLD'}}},
#  {'corpusid': 248366104,
#   'externalids': {'arxiv': None,
#    'mag': None,
#    'acl': None,
#    'pubmed': '35460592',
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1002/vetr.1680'},
#   'source': {'pdfurls': None,
#    'pdfsha': '9e589b902e5a3e4336921a70c88a26aa6e7d8c15',
#    'oainfo': {'license': 'CCBYNC',
#     'openaccessurl': 'https://onlinelibrary.wiley.com/doi/pdfdirect/10.1002/vetr.1680',
#     'status': 'HYBRID'}}},
#  {'corpusid': 126006188,
#   'externalids': {'arxiv': None,
#    'mag': '2803404607',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.11648/j.ajtas.20180704.13'},
#   'source': {'pdfurls': None,
#    'pdfsha': 'fb4a97839f488d958d186ec50f3829d0cbe373c3',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'http://article.sciencepublishinggroup.com/pdf/10.11648.j.ajtas.20180704.13.pdf',
#     'status': 'GOLD'}}},
#  {'corpusid': 247455878,
#   'externalids': {'arxiv': None,
#    'mag': None,
#    'acl': None,
#    'pubmed': '35495841',
#    'pubmedcentral': '9051704',
#    'dblp': None,
#    'doi': '10.4103/jfmpc.jfmpc_2033_20'},
#   'source': {'pdfurls': None,
#    'pdfsha': 'f1c890c38d6e0de6f7bb712b5a89453e05275488',
#    'oainfo': {'license': 'CCBYNCSA',
#     'openaccessurl': 'https://doi.org/10.4103/jfmpc.jfmpc_2033_20',
#     'status': 'GOLD'}}},
#  {'corpusid': 247229911,
#   'externalids': {'arxiv': None,
#    'mag': None,
#    'acl': None,
#    'pubmed': '35284620',
#    'pubmedcentral': '8896857',
#    'dblp': None,
#    'doi': '10.1016/j.imu.2022.100902'},
#   'source': {'pdfurls': None,
#    'pdfsha': 'ca3cf8c515a6e03f4fbd59236b4316b1c018740a',
#    'oainfo': {'license': 'CCBYNCND',
#     'openaccessurl': 'https://doi.org/10.1016/j.imu.2022.100902',
#     'status': 'GOLD'}}},
#  {'corpusid': 256919920,
#   'externalids': {'arxiv': None,
#    'mag': None,
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1038/s41598-017-03754-1'},
#   'source': {'pdfurls': None,
#    'pdfsha': '177ae8799804a71c7ceac3d8e14ac261cf6c46f5',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://www.nature.com/articles/s41598-017-03754-1.pdf',
#     'status': 'GOLD'}}},
#  {'corpusid': 256920094,
#   'externalids': {'arxiv': None,
#    'mag': None,
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1038/s41598-017-06505-4'},
#   'source': {'pdfurls': None,
#    'pdfsha': '67a4e4392576f3ccde65d1ad072ceb9f6a5e1040',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://www.nature.com/articles/s41598-017-06505-4.pdf',
#     'status': 'GOLD'}}},
#  {'corpusid': 234338817,
#   'externalids': {'arxiv': None,
#    'mag': '3127062364',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1088/1742-6596/1736/1/012027'},
#   'source': {'pdfurls': None,
#    'pdfsha': '9ae8c871f76423bc98aa04aebbd801d9fa005a06',
#    'oainfo': {'license': None,
#     'openaccessurl': 'https://doi.org/10.1088/1742-6596/1736/1/012027',
#     'status': 'GOLD'}}},
#  {'corpusid': 117682842,
#   'externalids': {'arxiv': '1811.10962',
#    'mag': '2950948493',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1364/optica.6.000524'},
#   'source': {'pdfurls': None,
#    'pdfsha': 'e447afb52f25581d7c2efed4f66b7593e64ecdd8',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://doi.org/10.1364/optica.6.000524',
#     'status': 'GOLD'}}},
#  {'corpusid': 73453457,
#   'externalids': {'arxiv': None,
#    'mag': '2913995583',
#    'acl': None,
#    'pubmed': '30765471',
#    'pubmedcentral': '6717564',
#    'dblp': None,
#    'doi': '10.3324/haematol.2018.214320'},
#   'source': {'pdfurls': None,
#    'pdfsha': 'cfb8deddc3418559fbc152a574b9a17311d71baa',
#    'oainfo': {'license': 'CCBYNC',
#     'openaccessurl': 'https://haematologica.org/article/download/9042/64564',
#     'status': 'GOLD'}}},
#  {'corpusid': 247358422,
#   'externalids': {'arxiv': None,
#    'mag': None,
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.31004/edukatif.v4i1.1461'},
#   'source': {'pdfurls': ['https://edukatif.org/index.php/edukatif/article/viewFile/1461/pdf'],
#    'pdfsha': '6cfbb6c195d967909b97ed531088c01f7e91cf62',
#    'oainfo': {'license': 'CCBYSA',
#     'openaccessurl': 'https://edukatif.org/index.php/edukatif/article/download/1461/pdf',
#     'status': 'HYBRID'}}},
#  {'corpusid': 247358657,
#   'externalids': {'arxiv': '2302.01150',
#    'mag': None,
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': 'journals/corr/abs-2302-01150',
#    'doi': '10.3233/sw-222993'},
#   'source': {'pdfurls': ['https://export.arxiv.org/pdf/2302.01150v1.pdf'],
#    'pdfsha': '9a33c0803f7094fe4e31bbe5b7a54765c25cb4b3',
#    'oainfo': {'license': 'implied-oa',
#     'openaccessurl': 'https://content.iospress.com/download/semantic-web/sw222993?id=semantic-web/sw222993',
#     'status': 'HYBRID'}}},
#  {'corpusid': 253277849,
#   'externalids': {'arxiv': None,
#    'mag': None,
#    'acl': None,
#    'pubmed': '36358721',
#    'pubmedcentral': '9659154',
#    'dblp': None,
#    'doi': '10.3390/cancers14215302'},
#   'source': {'pdfurls': None,
#    'pdfsha': '4b7216b9f35a193182fe02f3ec71c9422270ca7f',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://www.mdpi.com/2072-6694/14/21/5302/pdf?version=1666949778',
#     'status': 'GOLD'}}},
#  {'corpusid': 253280026,
#   'externalids': {'arxiv': None,
#    'mag': None,
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': '9624719',
#    'dblp': None,
#    'doi': '10.1210/jendso/bvac150.755'},
#   'source': {'pdfurls': None,
#    'pdfsha': '81744af99d751308321cb318a1a4e83bacb9524b',
#    'oainfo': {'license': 'CCBYNCND',
#     'openaccessurl': 'https://doi.org/10.1210/jendso/bvac150.755',
#     'status': 'GOLD'}}},
#  {'corpusid': 119123543,
#   'externalids': {'arxiv': '1605.08005',
#    'mag': None,
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': None},
#   'source': {'pdfurls': ['https://arxiv.org/pdf/1605.08005v1.pdf'],
#    'pdfsha': 'f761bcaa920d0c06522461f4d80972058b8fed0e',
#    'oainfo': None}},
#  {'corpusid': 86797059,
#   'externalids': {'arxiv': None,
#    'mag': '2918711359',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.29252/jrds.15.2.112'},
#   'source': {'pdfurls': None,
#    'pdfsha': 'c0a29f6f9d9d42bb8cf4df3af3a5e4d51f9cbc6a',
#    'oainfo': {'license': None,
#     'openaccessurl': 'http://jrds.ir/files/site1/user_files_3e2cc3/halezamani-A-10-1247-1-c2eb34a.pdf',
#     'status': 'GOLD'}}},
#  {'corpusid': 219416647,
#   'externalids': {'arxiv': None,
#    'mag': '3025957083',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1088/1742-6596/1515/5/052065'},
#   'source': {'pdfurls': None,
#    'pdfsha': '04d5e7129eb4c3c67b95ae28aec64ab99f16bd12',
#    'oainfo': {'license': None,
#     'openaccessurl': 'https://doi.org/10.1088/1742-6596/1515/5/052065',
#     'status': 'GOLD'}}},
#  {'corpusid': 242084701,
#   'externalids': {'arxiv': None,
#    'mag': None,
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.53387/sa.v2i4.33'},
#   'source': {'pdfurls': ['https://saberesandantes.org/index.php/sa/article/download/33/33'],
#    'pdfsha': 'b2f881423f9aaba043861e71ef9b1ca011d36fd7',
#    'oainfo': {'license': 'CCBYNCSA',
#     'openaccessurl': 'https://saberesandantes.org/index.php/sa/article/download/33/33',
#     'status': 'HYBRID'}}},
#  {'corpusid': 119980042,
#   'externalids': {'arxiv': None,
#    'mag': '1965529749',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1155/2013/494976'},
#   'source': {'pdfurls': ['http://downloads.hindawi.com/archive/2013/494976.pdf'],
#    'pdfsha': '634dcb9699cdb803086094864e9008bf5bde625f',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'http://downloads.hindawi.com/archive/2013/494976.pdf',
#     'status': 'GOLD'}}},
#  {'corpusid': 119989023,
#   'externalids': {'arxiv': '1405.2155',
#    'mag': '1987734675',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1016/j.physletb.2015.02.033'},
#   'source': {'pdfurls': ['https://arxiv.org/pdf/1405.2155v1.pdf'],
#    'pdfsha': '4c35a205a950f5e41dcc0b83e2e3e22411c07a12',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://doi.org/10.1016/j.physletb.2015.02.033',
#     'status': 'GOLD'}}},
#  {'corpusid': 16480581,
#   'externalids': {'arxiv': None,
#    'mag': '1901709490',
#    'acl': None,
#    'pubmed': '26215533',
#    'pubmedcentral': '4517169',
#    'dblp': None,
#    'doi': '10.1038/srep12578'},
#   'source': {'pdfurls': None,
#    'pdfsha': '0b4e1efbeddee6a594f01a2080062f4132dee10d',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://www.nature.com/articles/srep12578.pdf',
#     'status': 'GOLD'}}},
#  {'corpusid': 259323299,
#   'externalids': {'arxiv': None,
#    'mag': None,
#    'acl': None,
#    'pubmed': '37401986',
#    'pubmedcentral': '10409806',
#    'dblp': None,
#    'doi': '10.1007/s00424-023-02837-5'},
#   'source': {'pdfurls': None,
#    'pdfsha': '78dcb3411ec519cd9b52e562ac2f978963365ada',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://link.springer.com/content/pdf/10.1007/s00424-023-02837-5.pdf',
#     'status': 'HYBRID'}}},
#  {'corpusid': 254820438,
#   'externalids': {'arxiv': None,
#    'mag': None,
#    'acl': None,
#    'pubmed': '36559303',
#    'pubmedcentral': '9780892',
#    'dblp': None,
#    'doi': '10.3390/pharmaceutics14122809'},
#   'source': {'pdfurls': None,
#    'pdfsha': 'd6db64cb4287d5c84e8b7201932eed46dafb84a3',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://www.mdpi.com/1999-4923/14/12/2809/pdf?version=1671098450',
#     'status': 'GOLD'}}},
#  {'corpusid': 18320059,
#   'externalids': {'arxiv': None,
#    'mag': '2514004462',
#    'acl': None,
#    'pubmed': '27605058',
#    'pubmedcentral': '5015024',
#    'dblp': None,
#    'doi': '10.1038/srep32747'},
# ...
#    'pdfsha': 'dc022a4cff420c23e181d1347392bc0603f981e6',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://zenodo.org/record/898780/files/693847948.pdf',
#     'status': 'GREEN'}}},
#  {'corpusid': 14708281,
#   'externalids': {'arxiv': None,
#    'mag': '1908118656',
#    'acl': None,
#    'pubmed': '26394751',
#    'pubmedcentral': '4579835',
#    'dblp': None,
#    'doi': '10.1186/s12967-015-0659-x'},
#   'source': {'pdfurls': None,
#    'pdfsha': 'f31032ca49621042a06e1800e2614c21b458a3f2',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://translational-medicine.biomedcentral.com/track/pdf/10.1186/s12967-015-0659-x',
#     'status': 'GOLD'}}},
#  {'corpusid': 244858305,
#   'externalids': {'arxiv': None,
#    'mag': None,
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.7176/jiea/11-2-09'},
#   'source': {'pdfurls': ['https://web.archive.org/web/20211206071442/https:/www.iiste.org/Journals/index.php/JIEA/article/download/57661/59545'],
#    'pdfsha': '73fd3129dd1d694f68c0ae16531f6d457db71db3',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://www.iiste.org/Journals/index.php/JIEA/article/download/57661/59545',
#     'status': 'HYBRID'}}},
#  {'corpusid': 255853707,
#   'externalids': {'arxiv': None,
#    'mag': None,
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1186/s12935-022-02619-6'},
#   'source': {'pdfurls': None,
#    'pdfsha': 'e21a1d1a7733cba1cc9577e776ab5b59c157f06f',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://cancerci.biomedcentral.com/counter/pdf/10.1186/s12935-022-02619-6',
#     'status': 'GOLD'}}},
#  {'corpusid': 15627761,
#   'externalids': {'arxiv': None,
#    'mag': '1981603026',
#    'acl': None,
#    'pubmed': '22606023',
#    'pubmedcentral': '3344259',
#    'dblp': None,
#    'doi': '10.3390/ijms13044968'},
#   'source': {'pdfurls': None,
#    'pdfsha': 'd7cd0c437eadde48f98a006c569fd697df17dbf5',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'http://www.mdpi.com/1422-0067/13/4/4968/pdf',
#     'status': 'GOLD'}}},
#  {'corpusid': 254278693,
#   'externalids': {'arxiv': None,
#    'mag': None,
#    'acl': None,
#    'pubmed': '36643109',
#    'pubmedcentral': '9836138',
#    'dblp': None,
#    'doi': '10.4103/japtr.japtr_402_22'},
#   'source': {'pdfurls': None,
#    'pdfsha': '4914f440f0d4c5ec5b35e8d126c7d0bfae247dd0',
#    'oainfo': {'license': 'CCBYNCSA', 'openaccessurl': None, 'status': None}}},
#  {'corpusid': 237100019,
#   'externalids': {'arxiv': None,
#    'mag': None,
#    'acl': None,
#    'pubmed': '35544742',
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1101/2021.08.13.456215'},
#   'source': {'pdfurls': None,
#    'pdfsha': 'eec035664161a2906cf8dd4f67372e197fb2b85f',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://www.biorxiv.org/content/biorxiv/early/2021/08/13/2021.08.13.456215.full.pdf',
#     'status': 'GREEN'}}},
#  {'corpusid': 6019209,
#   'externalids': {'arxiv': None,
#    'mag': '2001445022',
#    'acl': None,
#    'pubmed': '23292075',
#    'pubmedcentral': '3594821',
#    'dblp': None,
#    'doi': '10.1007/s11033-012-2382-5'},
#   'source': {'pdfurls': None,
#    'pdfsha': '132561324539f17cf546a5c407e01c52baebe105',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://link.springer.com/content/pdf/10.1007/s11033-012-2382-5.pdf',
#     'status': 'HYBRID'}}},
#  {'corpusid': 245582908,
#   'externalids': {'arxiv': None,
#    'mag': None,
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.5005/jp-journals-10015-1898'},
#   'source': {'pdfurls': ['https://web.archive.org/web/20220105203754/https:/www.wjoud.com/doi/pdf/10.5005/jp-journals-10015-1898'],
#    'pdfsha': 'cd409a3942991ba708c2447507ea6a3f81612431',
#    'oainfo': {'license': None,
#     'openaccessurl': 'https://doi.org/10.5005/jp-journals-10015-1898',
#     'status': 'GOLD'}}},
#  {'corpusid': 228428893,
#   'externalids': {'arxiv': None,
#    'mag': '3042280971',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.46924/jihk.v4i2.20'},
#   'source': {'pdfurls': ['https://journal.stihbiak.ac.id/index.php/kyadiren/article/download/20/37'],
#    'pdfsha': '22b9ebc12363fee5f5bf423e9f19d30136b557c9',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://journal.stihbiak.ac.id/index.php/kyadiren/article/download/20/37',
#     'status': 'GOLD'}}},
#  {'corpusid': 11001695,
#   'externalids': {'arxiv': None,
#    'mag': '2185847524',
#    'acl': None,
#    'pubmed': '26620570',
#    'pubmedcentral': '4666015',
#    'dblp': None,
#    'doi': '10.1186/s13287-015-0246-3'},
#   'source': {'pdfurls': None,
#    'pdfsha': 'f80b702871295b2031c86aa697b80b7cd0aef128',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://stemcellres.biomedcentral.com/track/pdf/10.1186/s13287-015-0246-3',
#     'status': 'GOLD'}}},
#  {'corpusid': 18801212,
#   'externalids': {'arxiv': None,
#    'mag': '2093820290',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': '3452168',
#    'dblp': None,
#    'doi': '10.1007/s10194-004-0101-2'},
#   'source': {'pdfurls': ['https://thejournalofheadacheandpain.springeropen.com/track/pdf/10.1007/s10194-004-0101-2?site=thejournalofheadacheandpain.springeropen.com'],
#    'pdfsha': '5306c868c4786eb70e6248b398790221cb77aa4a',
#    'oainfo': {'license': None,
#     'openaccessurl': 'https://thejournalofheadacheandpain.biomedcentral.com/track/pdf/10.1007/s10194-004-0101-2',
#     'status': 'BRONZE'}}},
#  {'corpusid': 201116562,
#   'externalids': {'arxiv': None,
#    'mag': '2965548755',
#    'acl': None,
#    'pubmed': '31456658',
#    'pubmedcentral': '6700226',
#    'dblp': None,
#    'doi': '10.3389/fnins.2019.00850'},
#   'source': {'pdfurls': None,
#    'pdfsha': '380840824bab188933ca108da4ed6de1741cd039',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://www.frontiersin.org/articles/10.3389/fnins.2019.00850/pdf',
#     'status': 'GOLD'}}},
#  {'corpusid': 257312762,
#   'externalids': {'arxiv': None,
#    'mag': None,
#    'acl': None,
#    'pubmed': '36871055',
#    'pubmedcentral': '9985218',
#    'dblp': None,
#    'doi': '10.1186/s13690-023-01052-z'},
#   'source': {'pdfurls': None,
#    'pdfsha': '0725dc3ef49ae2e1452ee3e3c928e8b3d83fa2c9',
#    'oainfo': None}},
#  {'corpusid': 61665693,
#   'externalids': {'arxiv': None,
#    'mag': '2077345516',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1016/s2212-5671(14)00357-8'},
#   'source': {'pdfurls': None,
#    'pdfsha': '9116ffe89621b7c20cf6d9d464c81cf14ebdbff2',
#    'oainfo': {'license': None,
#     'openaccessurl': 'https://doi.org/10.1016/s2212-5671(14)00357-8',
#     'status': 'GOLD'}}},
#  {'corpusid': 56268174,
#   'externalids': {'arxiv': None,
#    'mag': '2166288723',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.3844/ajeassp.2010.521.528'},
#   'source': {'pdfurls': None,
#    'pdfsha': 'c4c936998c5f12fafa83f5799d3edba116ce619b',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://thescipub.com/pdf/ajeassp.2010.521.528.pdf',
#     'status': 'HYBRID'}}},
#  {'corpusid': 17965648,
#   'externalids': {'arxiv': 'hep-th/0010120',
#    'mag': '2949462442',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': None},
#   'source': {'pdfurls': ['https://arxiv.org/pdf/hep-th/0010120v2.pdf'],
#    'pdfsha': 'a302dbc50f792e8dc2c394a3384e73dca7804436',
#    'oainfo': None}},
#  {'corpusid': 119223509,
#   'externalids': {'arxiv': '1410.5441',
#    'mag': '3099599717',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1051/epjconf/20159301019'},
#   'source': {'pdfurls': None,
#    'pdfsha': '95fd3b2f12eed255989206b5007655c122721d0b',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://www.epj-conferences.org/articles/epjconf/pdf/2015/12/epjconf_cgs2015_01019.pdf',
#     'status': 'GOLD'}}},
#  {'corpusid': 118871923,
#   'externalids': {'arxiv': 'hep-th/0007016',
#    'mag': '3021953681',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1142/s0217751x01002981'},
#   'source': {'pdfurls': ['https://arxiv.org/pdf/hep-th/0007016v2.pdf'],
#    'pdfsha': '3e783e0b2a27e3ff42a84c496696e2b7203b0bdb',
#    'oainfo': {'license': None,
#     'openaccessurl': 'http://arxiv.org/pdf/hep-th/0007016',
#     'status': 'GREEN'}}},
#  {'corpusid': 118871983,
#   'externalids': {'arxiv': '1011.5772',
#    'mag': '2953163904',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1063/1.3575026'},
#   'source': {'pdfurls': ['https://arxiv.org/pdf/1011.5772v1.pdf'],
#    'pdfsha': '6b426a5c4608bb8ed4e0b7c9d497d65f16ac2ea9',
#    'oainfo': {'license': None,
#     'openaccessurl': 'http://arxiv.org/pdf/1011.5772',
#     'status': 'GREEN'}}},
#  {'corpusid': 250140140,
#   'externalids': {'arxiv': None,
#    'mag': None,
#    'acl': None,
#    'pubmed': '35950022',
#    'pubmedcentral': '9294955',
#    'dblp': None,
#    'doi': '10.1159/000525335'},
#   'source': {'pdfurls': None,
#    'pdfsha': '3fcbf362e53baede173c0f8c08701f4810687b7d',
#    'oainfo': {'license': 'CCBYNC',
#     'openaccessurl': 'https://www.karger.com/Article/Pdf/525335',
#     'status': 'GOLD'}}},
#  {'corpusid': 248050502,
#   'externalids': {'arxiv': None,
#    'mag': None,
#    'acl': None,
#    'pubmed': '35395830',
#    'pubmedcentral': '8993870',
#    'dblp': None,
#    'doi': '10.1038/s41419-022-04764-2'},
#   'source': {'pdfurls': None,
#    'pdfsha': 'bfb6fa4d5e09a43d25693a3db1077d51a9e110c8',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://www.nature.com/articles/s41419-022-04764-2.pdf',
#     'status': 'GOLD'}}},
#  {'corpusid': 251648307,
#   'externalids': {'arxiv': None,
#    'mag': None,
#    'acl': None,
#    'pubmed': '36059708',
#    'pubmedcentral': '9437299',
#    'dblp': None,
#    'doi': '10.3389/fonc.2022.953933'},
#   'source': {'pdfurls': None,
#    'pdfsha': '173e7490cc09fe0cdf1bd3a980ac7e80e3372cfd',
#    'oainfo': None}},
#  {'corpusid': 256042925,
#   'externalids': {'arxiv': None,
#    'mag': None,
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1007/jhep01(2018)140'},
#   'source': {'pdfurls': None,
#    'pdfsha': '9bfab83d27a1502b6c8e8bdace82486b4d1fb320',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://link.springer.com/content/pdf/10.1007/JHEP01(2018)140.pdf',
#     'status': 'GOLD'}}},
#  {'corpusid': 4734937,
#   'externalids': {'arxiv': None,
#    'mag': None,
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': '5273380',
#    'dblp': None,
#    'doi': '10.1080/13691180701410125'},
#   'source': {'pdfurls': None,
#    'pdfsha': 'fa802365990bb4c4f4d8db80b303e7b487282a27',
#    'oainfo': {'license': 'CCBYNC', 'openaccessurl': None, 'status': None}}},
#  {'corpusid': 4798972,
#   'externalids': {'arxiv': None,
#    'mag': '2508078609',
#    'acl': None,
#    'pubmed': '27510848',
#    'pubmedcentral': '4980614',
#    'dblp': None,
#    'doi': '10.1038/srep30897'},
#   'source': {'pdfurls': None,
#    'pdfsha': 'e744a7b97b134b3fbefe00e506f7448313ba1213',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://www.nature.com/articles/srep30897.pdf',
#     'status': 'GOLD'}}},
#  {'corpusid': 10628911,
#   'externalids': {'arxiv': None,
#    'mag': '2562572900',
#    'acl': None,
#    'pubmed': '28101081',
#    'pubmedcentral': '5209337',
#    'dblp': None,
#    'doi': '10.3389/fmicb.2016.02094'},
#   'source': {'pdfurls': None,
#    'pdfsha': '8febc0b083dc0800f63261c8b4241071605e4661',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://www.frontiersin.org/articles/10.3389/fmicb.2016.02094/pdf',
#     'status': 'GOLD'}}},
#  {'corpusid': 246775930,
#   'externalids': {'arxiv': None,
#    'mag': None,
#    'acl': None,
#    'pubmed': '35149661',
#    'pubmedcentral': '9112961',
#    'dblp': None,
#    'doi': '10.1097/phh.0000000000001510'},
#   'source': {'pdfurls': None,
#    'pdfsha': '706909655a6d43a1386de400883e38b1628b2aa2',
#    'oainfo': {'license': 'CCBYNCND',
#     'openaccessurl': 'https://journals.lww.com/jphmp/Abstract/9000/Disparities_in_SARS_CoV_2_Testing_for.99102.aspx',
#     'status': 'HYBRID'}}},
#  {'corpusid': 259424462,
#   'externalids': {'arxiv': None,
#    'mag': None,
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.59817/cjes.v13i2.456'},
#   'source': {'pdfurls': ['https://journals.ulab.edu.bd/index.php/crossings/article/download/456/393'],
#    'pdfsha': '70cbb6b09c2360defcaef4a586a507a391086dec',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://journals.ulab.edu.bd/index.php/crossings/article/download/456/393',
#     'status': 'HYBRID'}}},
#  {'corpusid': 225677513,
#   'externalids': {'arxiv': None,
#    'mag': '3035448113',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.3390/en13113004'},
#   'source': {'pdfurls': None,
#    'pdfsha': '05ab9da3f78852ae8175c70c0fd96c1bdc1bd430',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://www.mdpi.com/1996-1073/13/11/3004/pdf',
#     'status': 'GOLD'}}},
#  {'corpusid': 235214588,
#   'externalids': {'arxiv': None,
#    'mag': None,
#    'acl': None,
#    'pubmed': '34068869',
#    'pubmedcentral': '8153556',
#    'dblp': None,
#    'doi': '10.3390/bios11050155'},
#   'source': {'pdfurls': None,
#    'pdfsha': '3032d7047cbb9cd745cac395caac1c14f252ee69',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://www.mdpi.com/2079-6374/11/5/155/pdf',
#     'status': 'GOLD'}}},
#  {'corpusid': 116755612,
#   'externalids': {'arxiv': None,
#    'mag': '2755931260',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1088/1757-899x/236/1/012108'},
#   'source': {'pdfurls': None,
#    'pdfsha': '2af3c617326cee0a86644ac074a934dac9b37241',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://iopscience.iop.org/article/10.1088/1757-899X/236/1/012108/pdf',
#     'status': 'GOLD'}}},
#  {'corpusid': 56174375,
#   'externalids': {'arxiv': None,
#    'mag': '2905236420',
#    'acl': None,
#    'pubmed': '30559255',
#    'pubmedcentral': '6385976',
#    'dblp': None,
#    'doi': '10.1534/g3.118.200947'},
#   'source': {'pdfurls': None,
#    'pdfsha': '8275a104a2d74ec58c4ba16584d73f4cff043c0e',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://academic.oup.com/g3journal/article-pdf/9/2/523/35207065/g3journal0523.pdf',
#     'status': 'GOLD'}}},
#  {'corpusid': 246904217,
#   'externalids': {'arxiv': None,
#    'mag': None,
#    'acl': None,
#    'pubmed': '35172683',
#    'pubmedcentral': '8986266',
#    'dblp': None,
#    'doi': '10.1080/21645515.2021.2018895'},
#   'source': {'pdfurls': None,
#    'pdfsha': '631d360bc627ce318bdd533b2896d2d95294d787',
#    'oainfo': {'license': 'CCBYNCND',
#     'openaccessurl': 'https://www.tandfonline.com/doi/pdf/10.1080/21645515.2021.2018895?needAccess=true',
#     'status': 'HYBRID'}}},
#  {'corpusid': 226711642,
#   'externalids': {'arxiv': None,
#    'mag': '3092164081',
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1080/23311908.2020.1826091'},
#   'source': {'pdfurls': None,
#    'pdfsha': '51d218c1520af00f01d9214cef61258fdcd6c2b7',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://www.tandfonline.com/doi/pdf/10.1080/23311908.2020.1826091?needAccess=true',
#     'status': 'GOLD'}}},
#  {'corpusid': 248426823,
#   'externalids': {'arxiv': '2204.13146',
#    'mag': None,
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.4310/pamq.2022.v18.n4.a10'},
#   'source': {'pdfurls': ['https://arxiv.org/pdf/2204.13146v1.pdf'],
#    'pdfsha': '29d2520b23d31c9fc3efbcf600187912e600fa4d',
#    'oainfo': None}},
#  {'corpusid': 256426240,
#   'externalids': {'arxiv': None,
#    'mag': None,
#    'acl': None,
#    'pubmed': None,
#    'pubmedcentral': None,
#    'dblp': None,
#    'doi': '10.1007/s40820-018-0193-5'},
#   'source': {'pdfurls': None,
#    'pdfsha': 'a8fef772d8427d9950a060185546ab2ba769385b',
#    'oainfo': {'license': 'CCBY',
#     'openaccessurl': 'https://link.springer.com/content/pdf/10.1007/s40820-018-0193-5.pdf',
#     'status': 'GOLD'}}},
#  ...]
