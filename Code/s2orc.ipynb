# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import json
import aiohttp
import asyncio
import os

# %%
api_semanticscholar = ""

# %%
# Set up the URL and the headers
url = 'https://api.semanticscholar.org/datasets/v1/release/'
headers = {'x-api-key': api_semanticscholar}

# Send the GET request
response = requests.get(url, headers=headers)
latest = response.json()[-1]

# %%
url = 'https://api.semanticscholar.org/datasets/v1/release/' + latest + '/dataset/s2orc'
response = requests.get(url, headers=headers)

# %%
json_data = response.json()
json_formatted_str = json.dumps(json_data, indent=2)

# %%
print(json_data['README'])
# Out:
# Semantic Scholar Academic Graph Datasets
#
# The "s2orc" dataset contains parsed full-body text from selected papers.
#
# A subset of this data was previously released (in a different format) as S2ORC https://github.com/allenai/s2orc
#
# The body text is parsed from PDF documents using Grobid, documented at https://grobid.readthedocs.io.
# Its output is converted from XML into a single string with a set of annotation spans.
#
# SCHEMA
#  - externalIds: IDs of this paper in different catalogs
#  - content:
#    - source:
# 	   - pdfUrls: URLs to the PDF
# 	   - oaInfo: license/url/status information from Unpaywall
#    - text: Full body text as a single string
#    - annotations: Annotated spans of the full body text
#
#
# LICENSE
# This collection is licensed under ODC-BY. (https://opendatacommons.org/licenses/by/1.0/)
#
# By downloading this data you acknowledge that you have read and agreed to all the terms in this license.
#
# ATTRIBUTION
# ...

# %%
{"corpusid":111592336,
"externalids":	{"arxiv":null,
                "mag":"2248700607",
                "acl":null,
                "pubmed":null,
                "pubmedcentral":null,
                "dblp":null,
                "doi":"10.17509/bs_jpbsp.v15i2.1235"},
"content":{"source":{"pdfurls":null,
                     "pdfsha":"d95869434377f6aa79bb806cf2dc8d246ed4d589",
                     "oainfo":{"license":"CCBYSA",
                               "openaccessurl":"https://doi.org/10.17509/bs_jpbsp.v15i2.1235",
                               "status":"GOLD"}},
                               "text":"\nENGLISH LANGUAGE COMPETENCY AND OUTSOURCED CALL .\n",
                               "annotations":{"abstract":"[{\"end\":4320,\"start\":637}]",
                                              "author":"[{\"end\":196,\"start\":73},{\"end\":329,\"start\":197},{\"end\":418,\"start\":330}]",
                                              "authoraffiliation":"[{\"end\":195,\"start\":118},{\"end\":328,\"start\":213},{\"end\":417,\"start\":345}]",
                                              "authorfirstname":"[{\"end\":80,\"start\":73},{\"end\":205,\"start\":197},{\"end\":335,\"start\":330}]",
                                              "authorlastname":"[{\"end\":87,\"start\":81},{\"end\":211,\"start\":206},{\"end\":343,\"start\":336}]",
                                              "bibauthor":"[{\"end\":40557,\"start\":40546},{\"end\":40817,\"start\":40808},{\"end\":40825,\"start\":40817},{\"end\":40835,\"start\":40825},{\"end\":41267,\"start\":41259},{\"end\":41481,\"start\":41469},{\"end\":41801,\"start\":41791},{\"end\":42072,\"start\":42062}]",
                                              "bibauthorfirstname":"[{\"end\":40547,\"start\":40546},{\"end\":40549,\"start\":40548},{\"end\":40809,\"start\":40808}]",
                                              "bibauthorlastname":"[{\"end\":40555,\"start\":40550}]",
                                              "bibentry":"[{\"attributes\":{\"id\":\"b0\"},\"end\":40746,\"start\":40454},{\"attributes\":{\"id\":\"b1\"},\"end\":41198,\"start\":40748},{\"attributes\":{\"id\":\"b9\",\"matched_paper_id\":143692323}]",
                                              "bibref":"[{\"end\":4800,\"start\":4784},{\"attributes\":{\"ref_id\":\"b14\"},\"end\":6729,\"start\":6712}]",
                                              "bibtitle":"[{\"end\":40544,\"start\":40454},{\"end\":40806,\"start\":40748}]",
                                              "bibvenue":"[{\"end\":40587,\"start\":40557},{\"end\":40901,\"start\":40835}]",
                                              "figure":"[{\"attributes\":{\"id\":\"tab_0\",\"type\":\"table\"},\"end\":37817,\"start\":36998}]",
                                              "figureref":null,
                                              "formula":null,
                                              "paragraph":"[{\"end\":5607,\"start\":4336},{\"end\":5937,\"start\":5609}]",
                                              "publisher":null,
                                              "sectionheader":"[{\"end\":4334,\"start\":4322},{\"end\":18889,\"start\":18883}]",
                                              "table":"[{\"end\":37817,\"start\":37508},{\"end\":39366,\"start\":37878}]",
                                              "tableref":"[{\"attributes\":{\"ref_id\":\"tab_1\"},\"end\":21473,\"start\":21466}]",
                                              "title":"[{\"end\":70,\"start\":1},{\"end\":488,\"start\":419}]",
                                              "venue":null}}}

# %%
files_url = json_data['files']

# %%
files_url
# Out:
# ['https://ai2-s2ag.s3.amazonaws.com/staging/2024-01-24/s2orc/20240126_122714_00094_7rzhv_0001e621-8ad9-4d43-ae8d-164f447c10ee.gz?AWSAccessKeyId=ASIA5BJLZJPWYWB7KJ5D&Signature=MYavF6wdICqiZxbCm8zVJrpQSvw%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEGkaCXVzLXdlc3QtMiJIMEYCIQD%2F6mCQA%2FpnzjLxx2zUXJ%2BBtVGHqhtP5zggo%2FmKybSCMAIhAIJm8DrulIXhufiLMrlqA4CNWne6psLO%2BfqBMoaLhCQWKv8DCDIQABoMODk2MTI5Mzg3NTAxIgwMt5aixfYSZLPaWh0q3AMhLmiau%2BO6BMSpmApxpFX4ZLIvpTycROZSys%2B26EShQubGCn0RnIV80%2BApGIXERaBv%2FTiwWkvanD%2Fhq8X4noYqLYmgVaStNByOG5VDOlHYawWyhVpp72G3wpPzMVq4nKfP2x4pohvMJEuOvklQv4OKkJjqalRhlAOEBpnbS1kWxCvyEFkLCAsgFLzwKcs6aeGVvDMD6MHx8eUS1DKfVvnyEYqrOH%2BxJZV%2F2p4n6hyMsfDVz5h4hHDNvteQoDVN4e64lUqGjPtg715JAmlokSCg8udTH525J5vetu3r3JZyVSf9H5fbrKK887QXnvkRtRF9KS4V7ablHBxgHXYqt3Azp%2Be19JZ95%2B%2F%2F4Hx1svtlGVqcE3FN3Ca1iSlHWSd1VrPmDSH33E3yJrFZf%2FR8YKSlQl%2B4TS%2BqQMVngBMPGLpvJKqocwNK5A1%2FmeD2wmMA0H14d%2BxMe0lA3C73UA96QcZ1RSdzTqkuasWbDnpHd7Y6JxI2dswzVhNjHiQj95vWHxrrT3TJs%2FNYeDONMSGfkh2Zpm5paan0sRL
# ...

# %%
files_url[0].split('/')[-1].split('?')[0]
# Out:
# '20240126_122714_00094_7rzhv_0001e621-8ad9-4d43-ae8d-164f447c10ee.gz'
