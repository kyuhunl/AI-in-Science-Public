# %%
import pandas as pd
import requests
from itertools import chain

# %%
#API keys
api_springer = "" #full text for open-access articles in XML format (api.springernature.com/openaccess/jats/doi/[DOI]?api_key=[API])
api_elsevier = "" #full text for any article I have access to in XML format (https://api.elsevier.com/content/article/doi/[DOI]?APIKey=[API]?view=FULL)
api_wiley = "" #full text, but PDF download only.
api_gpt = ""
#BioC API: offers PMC OA and Author Manuscript Collection in XML format via PubMed ID or PMC ID (https://www.ncbi.nlm.nih.gov/research/bionlp/RESTful/pmcoa.cgi/BioC_[format]/[ID]/[encoding])
api_semanticscholar = ""

# %%
# I can filter using multiple ORCIDs by using the '|' operator. (Up to 50 values)

def build_author_works_url(id_list):
    # specify endpoint
    endpoint = 'works'

    ids = '|'.join(id_list)

    # build the 'filter' parameter
    filters = (
      f'author.id:{ids}',
      'type:article', #excludes book-chapter, dissertation, book, dataset, paratext, other, reference-entry, report, peer-review, standard, editorial, erratum, grant, letter
      'is_paratext:false' #excludes paratext
    )

    # put the URL together
    return f'https://api.openalex.org/{endpoint}?filter={",".join(filters)}&mailto=kl4898@stern.nyu.edu'

# %%
def get_publications(id_longlist):
    # split the list into chunks of 50
    id_chunks = [id_longlist[i:i + 50] for i in range(0, len(id_longlist), 50)]
    df = pd.DataFrame()

    # get the URL
    for id_list in id_chunks:
        url_with_cursor = build_author_works_url(id_list) + "&cursor={}"

        # initialize
        cursor = '*'
        while cursor:
            url = url_with_cursor.format(cursor)
            response = requests.get(url).json()
            data = pd.DataFrame(response['results'])
            df = pd.concat([df, data])
            cursor = response['meta']['next_cursor']

    return df

# %%
#get source ID for nature and science
url = "https://api.openalex.org/sources?filter=display_name.search:nature|science"
response = requests.get(url).json()
for result in response['results']:
    print(result['id'], result['display_name'])
# Out:
# https://openalex.org/S137773608 Nature
# https://openalex.org/S3880285 Science
# https://openalex.org/S64187185 Nature Communications
# https://openalex.org/S137905309 Nature Genetics
# https://openalex.org/S203256638 Nature Medicine
# https://openalex.org/S106963461 Nature Biotechnology
# https://openalex.org/S103895331 Nature Materials
# https://openalex.org/S2298632 Nature Neuroscience
# https://openalex.org/S127827428 Nature Methods
# https://openalex.org/S41063453 Nature Immunology
# https://openalex.org/S7822423 Nature Nanotechnology
# https://openalex.org/S106296714 Lecture Notes in Computer Science
# https://openalex.org/S160464432 Nature Reviews Cancer
# https://openalex.org/S151741590 Nature Cell Biology
# https://openalex.org/S13479253 Environmental Science & Technology
# https://openalex.org/S26843219 Nature Reviews Neuroscience
# https://openalex.org/S93373720 Nature Reviews Immunology
# https://openalex.org/S109387254 Nature Protocols
# https://openalex.org/S8553189 Nature Reviews Genetics
# https://openalex.org/S120392215 Nature Photonics
# https://openalex.org/S156274416 Nature Physics
# https://openalex.org/S44783556 The Science of Nature
# https://openalex.org/S196724125 Nature Reviews Molecular Cell Biology
# https://openalex.org/S56802129 Nature Reviews Microbiology
# https://openalex.org/S139253143 Nature Structural & Molecular Biology

# %%
# Nature_ID = response['results'][0]['id'] #https://openalex.org/S137773608
# Science_ID = response['results'][1]['id'] #https://openalex.org/S3880285
Nature_ID = "https://openalex.org/S137773608"
Science_ID = "https://openalex.org/S3880285"

# %%
# Get works published in Nature and Science
def NS_works(year):
    df = pd.DataFrame()

    filters = (
        'type:article', #excludes book-chapter, dissertation, book, dataset, paratext, other, reference-entry, report, peer-review, standard, editorial, erratum, grant, letter
        'is_paratext:false', #excludes paratext
        f'primary_location.source.id:{Nature_ID}|{Science_ID}',
        f'publication_year:{year}'
    )

    url_with_cursor = f'https://api.openalex.org/works?filter={",".join(filters)}' + '&cursor={}&mailto=kl4898@stern.nyu.edu'
    # initialize
    cursor = '*'
    while cursor:
        url = url_with_cursor.format(cursor)
        response = requests.get(url).json()
        data = pd.DataFrame(response['results'])
        df = pd.concat([df, data])
        cursor = response['meta']['next_cursor']

    return df

# %%
ns_2018 = NS_works(2018)

# %%
ns_2020 = NS_works(2020)

# %%
ns_2020.to_parquet('ns_2020.parquet')

# %%
ns_2018.to_parquet('ns_2018.parquet')

# %%
ns_2018_parquet = pd.read_parquet('ns_2018.parquet')

# %%
ns_2018_parquet
# Out:
#                                   id  \
# 0   https://openalex.org/W2793369479
# 1   https://openalex.org/W2895486342
# 2   https://openalex.org/W2790166049
# 3   https://openalex.org/W2791483720
# 4   https://openalex.org/W2765314233
# ..                               ...
# 23  https://openalex.org/W4294091206
# 24  https://openalex.org/W4298340596
# 0   https://openalex.org/W4390767771
# 1   https://openalex.org/W4390767772
# 2   https://openalex.org/W4390861464
#
#                                                   doi  \
# 0                 https://doi.org/10.1038/nature26160
# 1           https://doi.org/10.1038/s41586-018-0579-z
# 2             https://doi.org/10.1126/science.aap9559
# 3             https://doi.org/10.1126/science.aar4060
# 4             https://doi.org/10.1126/science.aan3706
# ..                                                ...
# 23  https://doi.org/10.1126/science.2018.361.6398....
# 24    https://doi.org/10.1126/science.359.6383.1479-b
# 0   https://doi.org/10.1126/science.2018.361.6398....
# 1   https://doi.org/10.1126/science.2018.362.6418....
# 2        https://doi.org/10.1126/science.361.6398.194
#
#                                                 title  \
# 0   Unconventional superconductivity in magic-angl...
# 1   The UK Biobank resource with deep phenotyping ...
# 2            The spread of true and false news online
# 3      Cancer immunotherapy using checkpoint blockade
# 4   Gut microbiome influences efficacy of PD-1–bas...
# ..                                                ...
# 23                                    Editors' Choice
# 24     AAAS annual election: Preliminary announcement
# 0                                This Week in Science
# 1                                This Week in Science
# 2                                        New Products
#
#                                          display_name  publication_year  \
# 0   Unconventional superconductivity in magic-angl...              2018
# 1   The UK Biobank resource with deep phenotyping ...              2018
# 2            The spread of true and false news online              2018
# 3      Cancer immunotherapy using checkpoint blockade              2018
# 4   Gut microbiome influences efficacy of PD-1–bas...              2018
# ..                                                ...               ...
# 23                                    Editors' Choice              2018
# 24     AAAS annual election: Preliminary announcement              2018
# 0                                This Week in Science              2018
# 1                                This Week in Science              2018
# 2                                        New Products              2018
#
#    publication_date                                                ids  \
# 0        2018-03-05  {'doi': 'https://doi.org/10.1038/nature26160',...
# 1        2018-10-01  {'doi': 'https://doi.org/10.1038/s41586-018-05...
# 2        2018-03-09  {'doi': 'https://doi.org/10.1126/science.aap95...
# 3        2018-03-23  {'doi': 'https://doi.org/10.1126/science.aar40...
# 4        2018-01-05  {'doi': 'https://doi.org/10.1126/science.aan37...
# ..              ...                                                ...
# 23       2018-07-13  {'doi': 'https://doi.org/10.1126/science.2018....
# 24       2018-03-30  {'doi': 'https://doi.org/10.1126/science.359.6...
# 0        2018-07-13  {'doi': 'https://doi.org/10.1126/science.2018....
# 1        2018-11-30  {'doi': 'https://doi.org/10.1126/science.2018....
# 2        2018-07-13  {'doi': 'https://doi.org/10.1126/science.361.6...
#
#    language                                   primary_location     type  ...  \
# 0        en  {'is_accepted': False, 'is_oa': False, 'is_pub...  article  ...
# 1        en  {'is_accepted': True, 'is_oa': True, 'is_publi...  article  ...
# 2        en  {'is_accepted': True, 'is_oa': True, 'is_publi...  article  ...
# 3        en  {'is_accepted': True, 'is_oa': True, 'is_publi...  article  ...
# 4        en  {'is_accepted': True, 'is_oa': True, 'is_publi...  article  ...
# ..      ...                                                ...      ...  ...
# 23     None  {'is_accepted': False, 'is_oa': False, 'is_pub...  article  ...
# 24       en  {'is_accepted': True, 'is_oa': True, 'is_publi...  article  ...
# 0        en  {'is_accepted': True, 'is_oa': True, 'is_publi...  article  ...
# 1        en  {'is_accepted': True, 'is_oa': True, 'is_publi...  article  ...
# 2        en  {'is_accepted': True, 'is_oa': True, 'is_publi...  article  ...
#
#    referenced_works_count                                   referenced_works  \
# 0                      63  [https://openalex.org/W1488440066, https://ope...
# 1                      40  [https://openalex.org/W1966585637, https://ope...
# 2                      48  [https://openalex.org/W1105550512, https://ope...
# 3                      63  [https://openalex.org/W1423342398, https://ope...
# 4                      34  [https://openalex.org/W1498931318, https://ope...
# ..                    ...                                                ...
# 23                      0                                                 []
# 24                      0                                                 []
# 0                       0                                                 []
# 1                       0                                                 []
# 2                       0                                                 []
#
#                                         related_works  \
# 0   [https://openalex.org/W2609137446, https://ope...
# 1   [https://openalex.org/W4286002085, https://ope...
# 2   [https://openalex.org/W3210159890, https://ope...
# 3   [https://openalex.org/W4304783156, https://ope...
# 4   [https://openalex.org/W2768863811, https://ope...
# ..                                                ...
# 23  [https://openalex.org/W2899084033, https://ope...
# 24  [https://openalex.org/W2899084033, https://ope...
# 0   [https://openalex.org/W2748952813, https://ope...
# 1   [https://openalex.org/W3007404728, https://ope...
# 2   [https://openalex.org/W2948807893, https://ope...
#
#                                            ngrams_url  \
# 0   https://api.openalex.org/works/W2793369479/ngrams
# 1   https://api.openalex.org/works/W2895486342/ngrams
# 2   https://api.openalex.org/works/W2790166049/ngrams
# 3   https://api.openalex.org/works/W2791483720/ngrams
# 4   https://api.openalex.org/works/W2765314233/ngrams
# ..                                                ...
# 23  https://api.openalex.org/works/W4294091206/ngrams
# 24  https://api.openalex.org/works/W4298340596/ngrams
# 0   https://api.openalex.org/works/W4390767771/ngrams
# 1   https://api.openalex.org/works/W4390767772/ngrams
# 2   https://api.openalex.org/works/W4390861464/ngrams
#
#                               abstract_inverted_index  \
# 0   {'
#
#
#
# My': None, '
#
# 2.': None, '
#
# 3.': None, '...
# 1   {'
#
#
#
# My': None, '
#
# 2.': None, '
#
# 3.': None, '...
# 2   {'
#
#
#
# My': None, '
#
# 2.': None, '
#
# 3.': None, '...
# 3   {'
#
#
#
# My': None, '
#
# 2.': None, '
#
# 3.': None, '...
# 4   {'
#
#
#
# My': None, '
#
# 2.': None, '
#
# 3.': None, '...
# ..                                                ...
# 23                                               None
# 24                                               None
# 0                                                None
# 1                                                None
# 2   {'
#
#
#
# My': None, '
#
# 2.': None, '
#
# 3.': None, '...
#
#                                      cited_by_api_url  \
# 0   https://api.openalex.org/works?filter=cites:W2...
# 1   https://api.openalex.org/works?filter=cites:W2...
# 2   https://api.openalex.org/works?filter=cites:W2...
# 3   https://api.openalex.org/works?filter=cites:W2...
# 4   https://api.openalex.org/works?filter=cites:W2...
# ..                                                ...
# 23  https://api.openalex.org/works?filter=cites:W4...
# 24  https://api.openalex.org/works?filter=cites:W4...
# 0   https://api.openalex.org/works?filter=cites:W4...
# 1   https://api.openalex.org/works?filter=cites:W4...
# 2   https://api.openalex.org/works?filter=cites:W4...
#
#                                        counts_by_year  \
# 0   [{'cited_by_count': 110, 'year': 2024}, {'cite...
# 1   [{'cited_by_count': 86, 'year': 2024}, {'cited...
# 2   [{'cited_by_count': 68, 'year': 2024}, {'cited...
# 3   [{'cited_by_count': 89, 'year': 2024}, {'cited...
# 4   [{'cited_by_count': 74, 'year': 2024}, {'cited...
# ..                                                ...
# 23                                                 []
# 24                                                 []
# 0                                                  []
# 1                                                  []
# 2                                                  []
#
#                   updated_date created_date is_authors_truncated
# 0   2024-02-08T10:38:18.485726   2018-03-29                 None
# 1   2024-02-07T01:57:53.112661   2018-10-12                 None
# 2   2024-02-03T22:39:56.622618   2018-03-29                 None
# 3   2024-02-02T00:10:31.184263   2018-03-29                 None
# 4   2024-02-06T15:41:57.208498   2017-11-10                 None
# ..                         ...          ...                  ...
# 23  2024-02-01T07:57:48.243689   2022-09-01                 None
# 24  2024-02-03T14:51:40.528624   2022-10-02                 None
# 0   2024-01-31T17:16:54.359121   2024-01-13                 None
# 1   2024-02-02T00:35:09.281753   2024-01-13                 None
# 2   2024-02-01T12:37:02.873783   2024-01-15                 None
#
# [8853 rows x 47 columns]

# %%
ns_2018['authorships']
# Out:
# 0     [{'author_position': 'first', 'author': {'id':...
# 1     [{'author_position': 'first', 'author': {'id':...
# 2     [{'author_position': 'first', 'author': {'id':...
# 3     [{'author_position': 'first', 'author': {'id':...
# 4     [{'author_position': 'first', 'author': {'id':...
#                             ...
# 23    [{'author_position': 'first', 'author': {'id':...
# 24                                                   []
# 0     [{'author_position': 'first', 'author': {'id':...
# 1     [{'author_position': 'first', 'author': {'id':...
# 2                                                    []
# Name: authorships, Length: 8853, dtype: object

# %%
author_ids_2 = []
for authorships in ns_2018['authorships']:
    author_list = [d['author']['id'] for d in authorships]
    author_ids_2.append(author_list)

author_ids_2 = list(set(chain.from_iterable(author_ids_2)))

# %%
author_ids = []
for authorships in ns_2018_parquet['authorships']:
    author_list = [d['author']['id'] for d in authorships]
    author_ids.append(author_list)

author_ids = list(set(chain.from_iterable(author_ids)))

# %%
author_ids_2[:10]
# Out:
# ['https://openalex.org/A5017801365',
#  'https://openalex.org/A5039454027',
#  'https://openalex.org/A5035067308',
#  'https://openalex.org/A5085410573',
#  'https://openalex.org/A5078727884',
#  'https://openalex.org/A5026803226',
#  'https://openalex.org/A5027582796',
#  'https://openalex.org/A5005589678',
#  'https://openalex.org/A5059895815',
#  'https://openalex.org/A5091454644']

# %%
author_ids[:10]
# Out:
# ['https://openalex.org/A5017801365',
#  'https://openalex.org/A5039454027',
#  'https://openalex.org/A5035067308',
#  'https://openalex.org/A5085410573',
#  'https://openalex.org/A5078727884',
#  'https://openalex.org/A5026803226',
#  'https://openalex.org/A5027582796',
#  'https://openalex.org/A5005589678',
#  'https://openalex.org/A5059895815',
#  'https://openalex.org/A5091454644']

# %%
len(author_ids)
# Out:
# 25599

# %%
#save author_ids
with open('author_ids.txt', 'w') as f:
    for item in author_ids:
        f.write("%s\n" % item)

# %%
#load author_ids disregarding the newline character
with open('author_ids.txt', 'r') as f:
    author_ids = f.read().splitlines()

# %%
author_ids[:10]
# Out:
# ['https://openalex.org/A5017801365',
#  'https://openalex.org/A5039454027',
#  'https://openalex.org/A5035067308',
#  'https://openalex.org/A5085410573',
#  'https://openalex.org/A5078727884',
#  'https://openalex.org/A5026803226',
#  'https://openalex.org/A5027582796',
#  'https://openalex.org/A5005589678',
#  'https://openalex.org/A5059895815',
#  'https://openalex.org/A5091454644']

# %%
corr_author_ids = []
for authorships in ns_2018['authorships']:
    author_list = [d['author']['id'] for d in authorships if d['is_corresponding'] or d['author_position']=='last']
    corr_author_ids.append(author_list)

corr_author_ids = list(set(chain.from_iterable(corr_author_ids)))

# %%
corr_author_ids = []
for authorships in ns_2018_parquet['authorships']:
    author_list = [d['author']['id'] for d in authorships if d['is_corresponding'] or d['author_position']=='last']
    corr_author_ids.append(author_list)

corr_author_ids = list(set(chain.from_iterable(corr_author_ids)))

# %%
len(corr_author_ids)
# Out:
# 5571

# %%
def chunk_list(input_list, N):
    return [input_list[i:i+N] for i in range(0, len(input_list),N)]

# %%
author_chunks = chunk_list(author_ids,50)

# %%
#save author_chunks
with open('author_chunks.txt', 'w') as f:
    for item in author_chunks:
        f.write("%s\n" % item)

# %%
#load author_chunks disregarding the newline character
with open('author_chunks.txt', 'r') as f:
    author_chunks = f.read().splitlines()

# %%
author_chunks = [eval(x) for x in author_chunks]

# %%
author_chunks[511]
# Out:
# ['https://openalex.org/A5040773420',
#  'https://openalex.org/A5032776183',
#  'https://openalex.org/A5086448413',
#  'https://openalex.org/A5034222438',
#  'https://openalex.org/A5005890720',
#  'https://openalex.org/A5081751581',
#  'https://openalex.org/A5073262712',
#  'https://openalex.org/A5046220109',
#  'https://openalex.org/A5038900860',
#  'https://openalex.org/A5014791286',
#  'https://openalex.org/A5071887725',
#  'https://openalex.org/A5089338975',
#  'https://openalex.org/A5031810877',
#  'https://openalex.org/A5044625530',
#  'https://openalex.org/A5063601349',
#  'https://openalex.org/A5011747705',
#  'https://openalex.org/A5087961058',
#  'https://openalex.org/A5019904930',
#  'https://openalex.org/A5018009111',
#  'https://openalex.org/A5090289358',
#  'https://openalex.org/A5041100379',
#  'https://openalex.org/A5082914171',
#  'https://openalex.org/A5001219422',
#  'https://openalex.org/A5078615235',
#  'https://openalex.org/A5046281941',
#  'https://openalex.org/A5027205545',
#  'https://openalex.org/A5020926476',
#  'https://openalex.org/A5072840384',
#  'https://openalex.org/A5067157286',
#  'https://openalex.org/A5051312413',
#  'https://openalex.org/A5015343143',
#  'https://openalex.org/A5034102448',
#  'https://openalex.org/A5007898866',
#  'https://openalex.org/A5065774182',
#  'https://openalex.org/A5059104743',
#  'https://openalex.org/A5049364941',
#  'https://openalex.org/A5020754390',
#  'https://openalex.org/A5060409988',
#  'https://openalex.org/A5059108373',
#  'https://openalex.org/A5024684806',
#  'https://openalex.org/A5004155361',
#  'https://openalex.org/A5090834340',
#  'https://openalex.org/A5051412830',
#  'https://openalex.org/A5077227037',
#  'https://openalex.org/A5089373045',
#  'https://openalex.org/A5002417388',
#  'https://openalex.org/A5060068686',
#  'https://openalex.org/A5017904858',
#  'https://openalex.org/A5045161248']

# %%
def extract_author_ids(authorships):
    author_ids = []
    for authorship in authorships:
        author_ids.append(authorship['author']['id'])
    return author_ids

# %%
def add_author_id_list(chunk):
    chunk['author_ids'] = chunk['authorships'].apply(extract_author_ids)
    return chunk

# %%
for i in range(len(author_chunks)):
    try:
        df = get_publications(author_chunks[i])
        df = add_author_id_list(df)
        df.to_parquet(f'author_publications_{i}.parquet')
        # write progress in txt
        with open('ns2018_progress.txt', 'a') as f:
            f.write(f"chunk {i} done\n")
    except:
        with open('ns2018_errorlist.txt', 'a') as f:
            f.write(f"chunk {i} failed\n")
# Out:
# chunk 0 done
# chunk 1 done
# chunk 2 done
# chunk 3 done

# %%
errorlist = []
for i in reversed(range(len(author_chunks))):
    try:
        df = get_publications(author_chunks[i])
        df.to_csv(f"/Volumes/Samsung_T5/OpenAlex_Works/works_chunk_{i}.csv")
        print(f"chunk {i} done")
    except:
        errorlist.append(i)
        print(f"chunk {i} failed")
# Out:
# chunk 511 done
# chunk 510 done
# chunk 509 done
# chunk 508 done
# chunk 507 done
# chunk 506 done
# chunk 505 done
# chunk 504 done
# chunk 503 done
# chunk 502 done
# chunk 501 done
# chunk 500 done
# chunk 499 done
# chunk 498 done
# chunk 497 done
# chunk 496 done
# chunk 495 done
# chunk 494 done
# chunk 493 done
# chunk 492 done
# chunk 491 done
# chunk 490 done
# chunk 489 failed
# chunk 488 done
# chunk 487 done
# chunk 486 done
# chunk 485 done
# chunk 484 done
# chunk 483 done
# chunk 482 done
# chunk 481 done
# chunk 480 done
# chunk 479 done
# chunk 478 done
# chunk 477 done
# chunk 476 done
# chunk 475 done
# chunk 474 done
# chunk 473 done
# chunk 472 done
# chunk 471 done
# chunk 470 done
# chunk 469 done
# chunk 468 failed
# chunk 467 done
# chunk 466 done
# chunk 465 done
# chunk 464 done
# chunk 463 done
# chunk 462 done
# chunk 461 done
# chunk 460 done
# chunk 459 done
# chunk 458 done
# chunk 457 done
# chunk 456 done
# chunk 455 done
# chunk 454 done
# chunk 453 done
# chunk 452 done
# chunk 451 done
# chunk 450 done
# chunk 449 done
# chunk 448 done
# chunk 447 done
# chunk 446 done
# chunk 445 done
# chunk 444 done
# chunk 443 done
# chunk 442 done
# chunk 441 done
# chunk 440 done
# chunk 439 done
# chunk 438 done
# chunk 437 done
# chunk 436 done
# chunk 435 done
# chunk 434 done
# chunk 433 failed
# chunk 432 done
# chunk 431 done
# chunk 430 done
# chunk 429 done
# chunk 428 done
# chunk 427 done
# chunk 426 done
# chunk 425 done
# chunk 424 done
# chunk 423 done
# chunk 422 done
# chunk 421 done
# chunk 420 done
# chunk 419 done
# chunk 418 done
# chunk 417 done
# chunk 416 done
# chunk 415 done
# chunk 414 done
# chunk 413 done
# chunk 412 done
# chunk 411 done
# chunk 410 done
# chunk 409 done
# chunk 408 done
# chunk 407 done
# chunk 406 done
# chunk 405 done
# chunk 404 done
# chunk 403 done
# chunk 402 done
# chunk 401 done
# chunk 400 done
# chunk 399 failed
# chunk 398 done
# chunk 397 failed
# chunk 396 done
# chunk 395 done
# chunk 394 done
# chunk 393 done
# chunk 392 done
# chunk 391 done
# chunk 390 failed
# chunk 389 done
# chunk 388 done
# chunk 387 done
# chunk 386 done
# chunk 385 done
# chunk 384 done
# chunk 383 done
# chunk 382 done
# chunk 381 done
# chunk 380 done
# chunk 379 done
# chunk 378 done
# chunk 377 failed
# chunk 376 done
# chunk 375 done
# chunk 374 done
# chunk 373 done
# chunk 372 done
# chunk 371 done
# chunk 370 done
# chunk 369 done
# chunk 368 done
# chunk 367 done
# chunk 366 done
# chunk 365 failed
# chunk 364 done
# chunk 363 done
# chunk 362 done
# chunk 361 done
# chunk 360 done
# chunk 359 done
# chunk 358 done
# chunk 357 done
# chunk 356 done
# chunk 355 done
# chunk 354 done
# chunk 353 done
# chunk 352 done
# chunk 351 done
# chunk 350 done
# chunk 349 done
# chunk 348 done
# chunk 347 done
# chunk 346 done
# chunk 345 done
# chunk 344 done
# chunk 343 done
# chunk 342 done
# chunk 341 done
# chunk 340 failed
# chunk 339 done
# chunk 338 done
# chunk 337 done
# chunk 336 done
# chunk 335 done
# chunk 334 done
# chunk 333 done
# chunk 332 done
# chunk 331 done
# chunk 330 done
# chunk 329 done
# chunk 328 done
# chunk 327 done
# chunk 326 done
# chunk 325 done
# chunk 324 done
# chunk 323 done
# chunk 322 done
# chunk 321 done
# chunk 320 done
# chunk 319 done
# chunk 318 done
# chunk 317 done
# chunk 316 done
# chunk 315 done
# chunk 314 done
# chunk 313 done
# chunk 312 done
# chunk 311 done
# chunk 310 done
# chunk 309 done
# chunk 308 failed
# chunk 307 done
# chunk 306 done
# chunk 305 done
# chunk 304 done
# chunk 303 done
# chunk 302 done
# chunk 301 done
# chunk 300 done
# chunk 299 done
# chunk 298 done
# chunk 297 done
# chunk 296 done
# chunk 295 done
# chunk 294 done
# chunk 293 done
# chunk 292 done
# chunk 291 done
# chunk 290 done
# chunk 289 done
# chunk 288 done
# chunk 287 done
# chunk 286 done
# chunk 285 done
# chunk 284 done
# chunk 283 done
# chunk 282 done
# chunk 281 done
# chunk 280 done
# chunk 279 done
# chunk 278 done
# chunk 277 done
# chunk 276 done
# chunk 275 done
# chunk 274 done
# chunk 273 done
# chunk 272 failed
# chunk 271 failed

# %%
chunk_0 = pd.read_csv("/Volumes/Samsung_T5/OpenAlex_Works/works_chunk_0.csv")

# %%
chunk_0['authorships']
# Out:
# 0       [{'author_position': 'first', 'author': {'id':...
# 1       [{'author_position': 'first', 'author': {'id':...
# 2       [{'author_position': 'first', 'author': {'id':...
# 3       [{'author_position': 'first', 'author': {'id':...
# 4       [{'author_position': 'first', 'author': {'id':...
#                               ...
# 8329    [{'author_position': 'first', 'author': {'id':...
# 8330    [{'author_position': 'first', 'author': {'id':...
# 8331    [{'author_position': 'first', 'author': {'id':...
# 8332    [{'author_position': 'first', 'author': {'id':...
# 8333    [{'author_position': 'first', 'author': {'id':...
# Name: authorships, Length: 8334, dtype: object

# %%
#comprehend entry as list
eval(chunk_0['authorships'].loc[0])
# Out:
# [{'author_position': 'first',
#   'author': {'id': 'https://openalex.org/A5067792979',
#    'display_name': 'Michael J. Caterina',
#    'orcid': 'https://orcid.org/0000-0002-7845-5297'},
#   'institutions': [{'id': 'https://openalex.org/I4210150520',
#     'display_name': 'Cellular Research (United States)',
#     'ror': 'https://ror.org/04jvb9y72',
#     'country_code': 'US',
#     'type': 'company',
#     'lineage': ['https://openalex.org/I4210150520']}],
#   'countries': ['US'],
#   'is_corresponding': False,
#   'raw_author_name': 'Michael J. Caterina',
#   'raw_affiliation_string': 'Departments of Cellular and Molecular Pharmacology, San Francisco, USA',
#   'raw_affiliation_strings': ['Departments of Cellular and Molecular Pharmacology, San Francisco, USA']},
#  {'author_position': 'middle',
#   'author': {'id': 'https://openalex.org/A5039559342',
#    'display_name': 'Mark Schumacher',
#    'orcid': None},
#   'institutions': [],
#   'countries': ['US'],
#   'is_corresponding': False,
#   'raw_author_name': 'Mark A. Schumacher',
#   'raw_affiliation_string': 'Departments of Anesthesia, San Francisco, USA',
#   'raw_affiliation_strings': ['Departments of Anesthesia, San Francisco, USA']},
#  {'author_position': 'middle',
#   'author': {'id': 'https://openalex.org/A5074653699',
#    'display_name': 'Makoto Tominaga',
#    'orcid': 'https://orcid.org/0000-0003-3111-3772'},
#   'institutions': [{'id': 'https://openalex.org/I4210150520',
#     'display_name': 'Cellular Research (United States)',
#     'ror': 'https://ror.org/04jvb9y72',
#     'country_code': 'US',
#     'type': 'company',
#     'lineage': ['https://openalex.org/I4210150520']}],
#   'countries': ['US'],
#   'is_corresponding': False,
#   'raw_author_name': 'Makoto Tominaga',
#   'raw_affiliation_string': 'Departments of Cellular and Molecular Pharmacology, San Francisco, USA',
#   'raw_affiliation_strings': ['Departments of Cellular and Molecular Pharmacology, San Francisco, USA']},
#  {'author_position': 'middle',
#   'author': {'id': 'https://openalex.org/A5066883628',
#    'display_name': 'Tobias A. Rosen',
#    'orcid': None},
#   'institutions': [{'id': 'https://openalex.org/I4210150520',
#     'display_name': 'Cellular Research (United States)',
#     'ror': 'https://ror.org/04jvb9y72',
#     'country_code': 'US',
#     'type': 'company',
#     'lineage': ['https://openalex.org/I4210150520']}],
#   'countries': ['US'],
#   'is_corresponding': False,
#   'raw_author_name': 'Tobias A. Rosen',
#   'raw_affiliation_string': 'Departments of Cellular and Molecular Pharmacology, San Francisco, USA',
#   'raw_affiliation_strings': ['Departments of Cellular and Molecular Pharmacology, San Francisco, USA']},
#  {'author_position': 'middle',
#   'author': {'id': 'https://openalex.org/A5037181353',
#    'display_name': 'Jon D. Levine',
#    'orcid': 'https://orcid.org/0000-0003-0681-5545'},
#   'institutions': [{'id': 'https://openalex.org/I180670191',
#     'display_name': 'University of California, San Francisco',
#     'ror': 'https://ror.org/043mz5j54',
#     'country_code': 'US',
#     'type': 'education',
#     'lineage': ['https://openalex.org/I180670191',
#      'https://openalex.org/I2803209242']}],
#   'countries': ['US'],
#   'is_corresponding': False,
#   'raw_author_name': 'Jon D. Levine',
#   'raw_affiliation_string': 'Departments of Medicine, University of California, San Francisco, USA.',
#   'raw_affiliation_strings': ['Departments of Medicine, University of California, San Francisco, USA.']},
#  {'author_position': 'last',
#   'author': {'id': 'https://openalex.org/A5014886042',
#    'display_name': 'David Julius',
#    'orcid': 'https://orcid.org/0000-0002-6365-4867'},
#   'institutions': [{'id': 'https://openalex.org/I4210150520',
#     'display_name': 'Cellular Research (United States)',
#     'ror': 'https://ror.org/04jvb9y72',
#     'country_code': 'US',
#     'type': 'company',
#     'lineage': ['https://openalex.org/I4210150520']}],
#   'countries': ['US'],
#   'is_corresponding': False,
#   'raw_author_name': 'David Julius',
#   'raw_affiliation_string': 'Departments of Cellular and Molecular Pharmacology, San Francisco, USA',
#   'raw_affiliation_strings': ['Departments of Cellular and Molecular Pharmacology, San Francisco, USA']}]

# %%
chunk_0 = get_publications(author_chunks[0])

# %%
chunk_0 = add_author_id_list(chunk_0)

# %%
chunk_0.to_csv("works_chunk_0.csv")

# %%
chunk_0 = pd.read_csv("works_chunk_0.csv")

# %%
chunk_0['author_ids']
# Out:
# 0        ['https://openalex.org/A5021736013', 'https://...
# 1        ['https://openalex.org/A5004515522', 'https://...
# 2        ['https://openalex.org/A5004515522', 'https://...
# 3        ['https://openalex.org/A5083991449', 'https://...
# 4        ['https://openalex.org/A5042384828', 'https://...
#                                ...
# 14750    ['https://openalex.org/A5025839822', 'https://...
# 14751    ['https://openalex.org/A5046416298', 'https://...
# 14752                 ['https://openalex.org/A5013110276']
# 14753    ['https://openalex.org/A5004515522', 'https://...
# 14754    ['https://openalex.org/A5020849392', 'https://...
# Name: author_ids, Length: 14755, dtype: object

# %%
chunk_0[chunk_0['author_ids'].apply(lambda x: any(item in author_chunks[0] for item in x))]
# Out:
#        Unnamed: 0                                id  \
# 0               0  https://openalex.org/W2256016639
# 1               1  https://openalex.org/W2097950056
# 2               2  https://openalex.org/W2112334970
# 3               3  https://openalex.org/W2909678677
# 4               4  https://openalex.org/W2115830594
# ...           ...                               ...
# 14750           0  https://openalex.org/W3147227403
# 14751           1  https://openalex.org/W3168899959
# 14752           2   https://openalex.org/W325855580
# 14753           3  https://openalex.org/W4247458054
# 14754           4    https://openalex.org/W49606109
#
#                                                  doi  \
# 0                https://doi.org/10.1038/nature19057
# 1      https://doi.org/10.1016/s0140-6736(12)61689-4
# 2      https://doi.org/10.1016/s0140-6736(96)07492-2
# 3      https://doi.org/10.1016/s0140-6736(18)31788-4
# 4      https://doi.org/10.1016/s0140-6736(06)68770-9
# ...                                              ...
# 14750                                            NaN
# 14751                                            NaN
# 14752                                            NaN
# 14753               https://doi.org/10.2307/25512956
# 14754                                            NaN
#
#                                                    title  \
# 0      Analysis of protein-coding genetic variation i...
# 1      Disability-adjusted life years (DALYs) for 291...
# 2      Alternative projections of mortality and disab...
# 3      Food in the Anthropocene: the EAT–Lancet Commi...
# 4      Global and regional burden of disease and risk...
# ...                                                  ...
# 14750                          Astrophysics with MILAGRO
# 14751  Search for Emission of Ultra High Energy Radia...
# 14752  Simulations of multiparticle production at hig...
# 14753                                    The Herne's Egg
# 14754  Rapport sur le developpement dans le monde 199...
#
#                                             display_name  publication_year  \
# 0      Analysis of protein-coding genetic variation i...              2016
# 1      Disability-adjusted life years (DALYs) for 291...              2012
# 2      Alternative projections of mortality and disab...              1997
# 3      Food in the Anthropocene: the EAT–Lancet Commi...              2019
# 4      Global and regional burden of disease and risk...              2006
# ...                                                  ...               ...
# 14750                          Astrophysics with MILAGRO              1993
# 14751  Search for Emission of Ultra High Energy Radia...              1993
# 14752  Simulations of multiparticle production at hig...              1993
# 14753                                    The Herne's Egg              1993
# 14754  Rapport sur le developpement dans le monde 199...              1993
#
#       publication_date                                                ids  \
# 0           2016-08-01  {'openalex': 'https://openalex.org/W2256016639...
# 1           2012-12-01  {'openalex': 'https://openalex.org/W2097950056...
# 2           1997-05-01  {'openalex': 'https://openalex.org/W2112334970...
# 3           2019-02-01  {'openalex': 'https://openalex.org/W2909678677...
# 4           2006-05-01  {'openalex': 'https://openalex.org/W2115830594...
# ...                ...                                                ...
# 14750       1993-01-01  {'openalex': 'https://openalex.org/W3147227403...
# 14751       1993-05-01  {'openalex': 'https://openalex.org/W3168899959...
# 14752       1993-06-15  {'openalex': 'https://openalex.org/W325855580'...
# 14753       1993-01-01  {'openalex': 'https://openalex.org/W4247458054...
# 14754       1993-07-01  {'openalex': 'https://openalex.org/W49606109',...
#
#       language                                   primary_location  ...  \
# 0           en  {'is_oa': True, 'landing_page_url': 'https://d...  ...
# 1           en  {'is_oa': False, 'landing_page_url': 'https://...  ...
# 2           en  {'is_oa': False, 'landing_page_url': 'https://...  ...
# 3           en  {'is_oa': False, 'landing_page_url': 'https://...  ...
# 4           en  {'is_oa': False, 'landing_page_url': 'https://...  ...
# ...        ...                                                ...  ...
# 14750       en  {'is_oa': False, 'landing_page_url': 'http://u...  ...
# 14751       en  {'is_oa': False, 'landing_page_url': 'https://...  ...
# 14752       en  {'is_oa': False, 'landing_page_url': 'http://w...  ...
# 14753      NaN  {'is_oa': False, 'landing_page_url': 'https://...  ...
# 14754       en  {'is_oa': False, 'landing_page_url': 'https://...  ...
#
#                                         referenced_works  \
# 0      ['https://openalex.org/W1533942137', 'https://...
# 1      ['https://openalex.org/W1503206236', 'https://...
# 2      ['https://openalex.org/W1565391189', 'https://...
# 3      ['https://openalex.org/W595212506', 'https://o...
# 4      ['https://openalex.org/W1981986207', 'https://...
# ...                                                  ...
# 14750                                                 []
# 14751                                                 []
# 14752                                                 []
# 14753                                                 []
# 14754                                                 []
#
#                                            related_works  \
# 0      ['https://openalex.org/W2484239316', 'https://...
# 1      ['https://openalex.org/W2131839676', 'https://...
# 2      ['https://openalex.org/W2056522719', 'https://...
# 3      ['https://openalex.org/W4200315805', 'https://...
# 4      ['https://openalex.org/W2131839676', 'https://...
# ...                                                  ...
# 14750  ['https://openalex.org/W346237057', 'https://o...
# 14751  ['https://openalex.org/W126798772', 'https://o...
# 14752  ['https://openalex.org/W72940282', 'https://op...
# 14753  ['https://openalex.org/W2082860237', 'https://...
# 14754                                                 []
#
#                                               ngrams_url  \
# 0      https://api.openalex.org/works/W2256016639/ngrams
# 1      https://api.openalex.org/works/W2097950056/ngrams
# 2      https://api.openalex.org/works/W2112334970/ngrams
# 3      https://api.openalex.org/works/W2909678677/ngrams
# 4      https://api.openalex.org/works/W2115830594/ngrams
# ...                                                  ...
# 14750  https://api.openalex.org/works/W3147227403/ngrams
# 14751  https://api.openalex.org/works/W3168899959/ngrams
# 14752   https://api.openalex.org/works/W325855580/ngrams
# 14753  https://api.openalex.org/works/W4247458054/ngrams
# 14754    https://api.openalex.org/works/W49606109/ngrams
#
#                                  abstract_inverted_index  \
# 0      {'Large-scale': [0], 'reference': [1], 'data':...
# 1      {'Background': [0], 'Measuring': [1], 'disease...
# 2      {'Plausible': [0], 'projections': [1, 150, 204...
# 3      {'Food': [0, 207, 241, 310, 337, 353, 386, 483...
# 4      {'Our': [0, 322], 'aim': [1], 'was': [2, 157, ...
# ...                                                  ...
# 14750                                                NaN
# 14751                                                NaN
# 14752  {'A': [0], 'Monte': [1], 'Carlo': [2], 'genera...
# 14753                                                NaN
# 14754  {'This': [0, 131], 'is': [1, 39, 49, 76, 226],...
#
#                                         cited_by_api_url  \
# 0      https://api.openalex.org/works?filter=cites:W2...
# 1      https://api.openalex.org/works?filter=cites:W2...
# 2      https://api.openalex.org/works?filter=cites:W2...
# 3      https://api.openalex.org/works?filter=cites:W2...
# 4      https://api.openalex.org/works?filter=cites:W2...
# ...                                                  ...
# 14750  https://api.openalex.org/works?filter=cites:W3...
# 14751  https://api.openalex.org/works?filter=cites:W3...
# 14752  https://api.openalex.org/works?filter=cites:W3...
# 14753  https://api.openalex.org/works?filter=cites:W4...
# 14754  https://api.openalex.org/works?filter=cites:W4...
#
#                                           counts_by_year  \
# 0      [{'year': 2024, 'cited_by_count': 42}, {'year'...
# 1      [{'year': 2024, 'cited_by_count': 34}, {'year'...
# 2      [{'year': 2024, 'cited_by_count': 5}, {'year':...
# 3      [{'year': 2024, 'cited_by_count': 135}, {'year...
# 4      [{'year': 2024, 'cited_by_count': 13}, {'year'...
# ...                                                  ...
# 14750                                                 []
# 14751                                                 []
# 14752                                                 []
# 14753                                                 []
# 14754                                                 []
#
#                      updated_date created_date is_authors_truncated  \
# 0      2024-02-09T16:01:28.162872   2016-06-24                  NaN
# 1      2024-02-09T15:44:30.115740   2016-06-24                 True
# 2      2024-02-03T01:09:06.322989   2016-06-24                  NaN
# 3      2024-02-06T14:32:49.072483   2019-01-25                  NaN
# 4      2024-02-04T11:52:57.006034   2016-06-24                  NaN
# ...                           ...          ...                  ...
# 14750  2024-02-07T14:06:39.790932   2021-04-13                  NaN
# 14751  2024-02-09T02:45:52.138393   2021-06-22                  NaN
# 14752  2024-02-06T08:24:28.741848   2016-06-24                  NaN
# 14753  2024-02-02T14:47:22.326577   2022-05-12                  NaN
# 14754  2024-02-04T04:44:43.721923   2016-06-24                  NaN
#
#                                               author_ids
# 0      [https://openalex.org/A5021736013, https://ope...
# 1      [https://openalex.org/A5004515522, https://ope...
# 2      [https://openalex.org/A5004515522, https://ope...
# 3      [https://openalex.org/A5083991449, https://ope...
# 4      [https://openalex.org/A5042384828, https://ope...
# ...                                                  ...
# 14750  [https://openalex.org/A5025839822, https://ope...
# 14751  [https://openalex.org/A5046416298, https://ope...
# 14752                 [https://openalex.org/A5013110276]
# 14753  [https://openalex.org/A5004515522, https://ope...
# 14754  [https://openalex.org/A5020849392, https://ope...
#
# [14755 rows x 49 columns]

# %%
def chunk_check(i,j):
    chunk_i = pd.read_csv(f"/Volumes/Samsung_T5/OpenAlex_Works/works_chunk_{i}.csv")
    chunk_i = add_author_id_list(chunk_i)
    chunk_i = chunk_i[chunk_i['author_ids'].apply(lambda x: any(item in author_chunks[j] for item in x))]
    return len(chunk_i)

# %%
chunk_0['author_ids'] = chunk_0['author_ids'].apply(eval)

# %%
#count number of entries for each author
author_counts = {}
for author in author_ids:
    count = 0
    df = chunk_0[chunk_0['author_ids'].apply(lambda x: author in x)]
    count += len(df)
    author_counts[author] = count

#sort in descending order
author_counts = dict(sorted(author_counts.items(), key=lambda item: item[1], reverse=True))
print(author_counts)
# Out:
# {'https://openalex.org/A5059319698': 771, 'https://openalex.org/A5054256781': 545, 'https://openalex.org/A5045504233': 452, 'https://openalex.org/A5005730211': 436, 'https://openalex.org/A5032410036': 428, 'https://openalex.org/A5005354758': 409, 'https://openalex.org/A5078504185': 329, 'https://openalex.org/A5047434698': 324, 'https://openalex.org/A5055277410': 261, 'https://openalex.org/A5061115598': 251, 'https://openalex.org/A5058301915': 233, 'https://openalex.org/A5005897340': 223, 'https://openalex.org/A5082324446': 223, 'https://openalex.org/A5064241770': 206, 'https://openalex.org/A5091588944': 199, 'https://openalex.org/A5082072514': 194, 'https://openalex.org/A5061172218': 178, 'https://openalex.org/A5040055379': 175, 'https://openalex.org/A5014886042': 174, 'https://openalex.org/A5079634281': 173, 'https://openalex.org/A5040423859': 166, 'https://openalex.org/A5006444990': 165, 'https://openalex.org/A5080512785': 160, 'https://openalex.org/A5055710883': 156, 'https://openalex.org/A5044192296': 153, 'https://openalex.org/A5001392592': 148, 'https://openalex.org/A5014987559': 144, 'https://openalex.org/A5006562418': 143, 'https://openalex.org/A5041096535': 130, 'https://openalex.org/A5073211182': 112, 'https://openalex.org/A5010876920': 108, 'https://openalex.org/A5066787692': 99, 'https://openalex.org/A5071985087': 96, 'https://openalex.org/A5038035447': 94, 'https://openalex.org/A5006672507': 88, 'https://openalex.org/A5013677681': 85, 'https://openalex.org/A5060460614': 84, 'https://openalex.org/A5028812792': 81, 'https://openalex.org/A5010365288': 78, 'https://openalex.org/A5014722839': 77, 'https://openalex.org/A5062826296': 77, 'https://openalex.org/A5007938895': 76, 'https://openalex.org/A5046256348': 76, 'https://openalex.org/A5087082103': 73, 'https://openalex.org/A5057814101': 70, 'https://openalex.org/A5027400392': 70, 'https://openalex.org/A5055707428': 63, 'https://openalex.org/A5064456190': 62, 'https://openalex.org/A5024306947': 62, 'https://openalex.org/A5003252073': 61, 'https://openalex.org/A5052657395': 60, 'https://openalex.org/A5087677473': 59, 'https://openalex.org/A5029113835': 59, 'https://openalex.org/A5000161585': 58, 'https://openalex.org/A5059556029': 58, 'https://openalex.org/A5018363968': 57, 'https://openalex.org/A5003120045': 54, 'https://openalex.org/A5081316082': 53, 'https://openalex.org/A5003000553': 51, 'https://openalex.org/A5028850932': 50, 'https://openalex.org/A5063978061': 50, 'https://openalex.org/A5001682484': 49, 'https://openalex.org/A5086430781': 48, 'https://openalex.org/A5038534642': 48, 'https://openalex.org/A5033108171': 48, 'https://openalex.org/A5071651857': 47, 'https://openalex.org/A5029466336': 46, 'https://openalex.org/A5047858866': 46, 'https://openalex.org/A5087654538': 45, 'https://openalex.org/A5048392622': 45, 'https://openalex.org/A5000002636': 43, 'https://openalex.org/A5030472377': 42, 'https://openalex.org/A5039647180': 39, 'https://openalex.org/A5085237456': 39, 'https://openalex.org/A5090085741': 39, 'https://openalex.org/A5000325789': 38, 'https://openalex.org/A5085975040': 37, 'https://openalex.org/A5020918152': 36, 'https://openalex.org/A5084098015': 36, 'https://openalex.org/A5024604848': 36, 'https://openalex.org/A5062148401': 36, 'https://openalex.org/A5070639192': 35, 'https://openalex.org/A5090815387': 35, 'https://openalex.org/A5067763640': 35, 'https://openalex.org/A5014129073': 34, 'https://openalex.org/A5039526242': 34, 'https://openalex.org/A5083608565': 34, 'https://openalex.org/A5090238081': 33, 'https://openalex.org/A5038647031': 33, 'https://openalex.org/A5047871874': 33, 'https://openalex.org/A5001449157': 32, 'https://openalex.org/A5064750899': 31, 'https://openalex.org/A5037434404': 31, 'https://openalex.org/A5066527569': 30, 'https://openalex.org/A5003947352': 30, 'https://openalex.org/A5011823621': 30, 'https://openalex.org/A5027397785': 30, 'https://openalex.org/A5057000867': 30, 'https://openalex.org/A5034125759': 29, 'https:/ ...

# %%
import csv
import sys

# %%
def count_rows_in_csv(filename):
    csv.field_size_limit(sys.maxsize)

    with open(filename, 'r', encoding='utf-8') as file:
        csv_reader = csv.reader(file)
        row_count = sum(1 for row in csv_reader)
    return row_count

# %%
count_rows_in_csv("/Volumes/Samsung_T5/OpenAlex_Works/works_chunk_0.csv")
# Out:
# 8335

# %%
count = 0
for i in range(512):
    count += count_rows_in_csv(f"/Volumes/Samsung_T5/OpenAlex_Works/works_chunk_{i}.csv") - 1
    print(f"chunk {i} done")

print(count)
# Out:
# chunk 0 done
# chunk 1 done
# chunk 2 done
# chunk 3 done
# chunk 4 done
# chunk 5 done
# chunk 6 done
# chunk 7 done
# chunk 8 done
# chunk 9 done
# chunk 10 done
# chunk 11 done
# chunk 12 done
# chunk 13 done
# chunk 14 done
# chunk 15 done
# chunk 16 done
# chunk 17 done
# chunk 18 done
# chunk 19 done
# chunk 20 done
# chunk 21 done
# chunk 22 done
# chunk 23 done
# chunk 24 done
# chunk 25 done
# chunk 26 done
# chunk 27 done
# chunk 28 done
# chunk 29 done
# chunk 30 done
# chunk 31 done
# chunk 32 done
# chunk 33 done
# chunk 34 done
# chunk 35 done
# chunk 36 done
# chunk 37 done
# chunk 38 done
# chunk 39 done
# chunk 40 done
# chunk 41 done
# chunk 42 done
# chunk 43 done
# chunk 44 done
# chunk 45 done
# chunk 46 done
# chunk 47 done
# chunk 48 done
# chunk 49 done
# chunk 50 done
# chunk 51 done
# chunk 52 done
# chunk 53 done
# chunk 54 done
# chunk 55 done
# chunk 56 done
# chunk 57 done
# chunk 58 done
# chunk 59 done
# chunk 60 done
# chunk 61 done
# chunk 62 done
# chunk 63 done
# chunk 64 done
# chunk 65 done
# chunk 66 done
# chunk 67 done
# chunk 68 done
# chunk 69 done
# chunk 70 done
# chunk 71 done
# chunk 72 done
# chunk 73 done
# chunk 74 done
# chunk 75 done
# chunk 76 done
# chunk 77 done
# chunk 78 done
# chunk 79 done
# chunk 80 done
# chunk 81 done
# chunk 82 done
# chunk 83 done
# chunk 84 done
# chunk 85 done
# chunk 86 done
# chunk 87 done
# chunk 88 done
# chunk 89 done
# chunk 90 done
# chunk 91 done
# chunk 92 done
# chunk 93 done
# chunk 94 done
# chunk 95 done
# chunk 96 done
# chunk 97 done
# chunk 98 done
# chunk 99 done
# chunk 100 done
# chunk 101 done
# chunk 102 done
# chunk 103 done
# chunk 104 done
# chunk 105 done
# chunk 106 done
# chunk 107 done
# chunk 108 done
# chunk 109 done
# chunk 110 done
# chunk 111 done
# chunk 112 done
# chunk 113 done
# chunk 114 done
# chunk 115 done
# chunk 116 done
# chunk 117 done
# chunk 118 done
# chunk 119 done
# chunk 120 done
# chunk 121 done
# chunk 122 done
# chunk 123 done
# chunk 124 done
# chunk 125 done
# chunk 126 done
# chunk 127 done
# chunk 128 done
# chunk 129 done
# chunk 130 done
# chunk 131 done
# chunk 132 done
# chunk 133 done
# chunk 134 done
# chunk 135 done
# chunk 136 done
# chunk 137 done
# chunk 138 done
# chunk 139 done
# chunk 140 done
# chunk 141 done
# chunk 142 done
# chunk 143 done
# chunk 144 done
# chunk 145 done
# chunk 146 done
# chunk 147 done
# chunk 148 done
# chunk 149 done
# chunk 150 done
# chunk 151 done
# chunk 152 done
# chunk 153 done
# chunk 154 done
# chunk 155 done
# chunk 156 done
# chunk 157 done
# chunk 158 done
# chunk 159 done
# chunk 160 done
# chunk 161 done
# chunk 162 done
# chunk 163 done
# chunk 164 done
# chunk 165 done
# chunk 166 done
# chunk 167 done
# chunk 168 done
# chunk 169 done
# chunk 170 done
# chunk 171 done
# chunk 172 done
# chunk 173 done
# chunk 174 done
# chunk 175 done
# chunk 176 done
# chunk 177 done
# chunk 178 done
# chunk 179 done
# chunk 180 done
# chunk 181 done
# chunk 182 done
# chunk 183 done
# chunk 184 done
# chunk 185 done
# chunk 186 done
# chunk 187 done
# chunk 188 done
# chunk 189 done
# chunk 190 done
# chunk 191 done
# chunk 192 done
# chunk 193 done
# chunk 194 done
# chunk 195 done
# chunk 196 done
# chunk 197 done
# chunk 198 done
# chunk 199 done
# chunk 200 done
# chunk 201 done
# chunk 202 done
# chunk 203 done
# chunk 204 done
# chunk 205 done
# chunk 206 done
# chunk 207 done
# chunk 208 done
# chunk 209 done
# chunk 210 done
# chunk 211 done
# chunk 212 done
# chunk 213 done
# chunk 214 done
# chunk 215 done
# chunk 216 done
# chunk 217 done
# chunk 218 done
# chunk 219 done
# chunk 220 done
# chunk 221 done
# chunk 222 done
# chunk 223 done
# chunk 224 done
# chunk 225 done
# chunk 226 done
# chunk 227 done
# chunk 228 done
# chunk 229 done
# chunk 230 done
# chunk 231 done
# chunk 232 done
# chunk 233 done
# chunk 234 done
# chunk 235 done
# chunk 236 done
# chunk 237 done
# chunk 238 done
# chunk 239 done
# chunk 240 done
# chunk 241 done
# chunk 242 done
# chunk 243 done
# chunk 244 done
# chunk 245 done
# chunk 246 done
# chunk 247 done
# chunk 248 done
# chunk 249 done
# chunk 250 done
# chunk 251 done
# chunk 252 done
# chunk 253 done
# chunk 254 done
# chunk 255 done
# chunk 256 done
# chunk 257 done
# chunk 258 done
# chunk 259 done
# chunk 260 done
# chunk 261 done
# chunk 262 done
# chunk 263 done
# chunk 264 done
# chunk 265 done
# chunk 266 done
# chunk 267 done
# chunk 268 done
# chunk 269 done
# chunk 270 done
# chunk 271 done
# chunk 272 done
# chunk 273 done
# chunk 274 done
# chunk 275 done
# chunk 276 done
# chunk 277 done
# chunk 278 done
# chunk 279 done
# chunk 280 done
# chunk 281 done
# chunk 282 done
# chunk 283 done
# chunk 284 done
# chunk 285 done
# chunk 286 done
# chunk 287 done
# chunk 288 done
# chunk 289 done
# chunk 290 done
# chunk 291 done
# chunk 292 done
# chunk 293 done
# chunk 294 done
# chunk 295 done
# chunk 296 done
# chunk 297 done
# chunk 298 done
# chunk 299 done
# chunk 300 done
# chunk 301 done
# chunk 302 done
# chunk 303 done
# chunk 304 done
# chunk 305 done
# chunk 306 done
# chunk 307 done
# chunk 308 done
# chunk 309 done
# chunk 310 done
# chunk 311 done
# chunk 312 done
# chunk 313 done
# chunk 314 done
# chunk 315 done
# chunk 316 done
# chunk 317 done
# chunk 318 done
# chunk 319 done
# chunk 320 done
# chunk 321 done
# chunk 322 done
# chunk 323 done
# chunk 324 done
# chunk 325 done
# chunk 326 done
# chunk 327 done
# chunk 328 done
# chunk 329 done
# chunk 330 done
# chunk 331 done
# chunk 332 done
# chunk 333 done
# chunk 334 done
# chunk 335 done
# chunk 336 done
# chunk 337 done
# chunk 338 done
# chunk 339 done
# chunk 340 done
# chunk 341 done
# chunk 342 done
# chunk 343 done
# chunk 344 done
# chunk 345 done
# chunk 346 done
# chunk 347 done
# chunk 348 done
# chunk 349 done
# chunk 350 done
# chunk 351 done
# chunk 352 done
# chunk 353 done
# chunk 354 done
# chunk 355 done
# chunk 356 done
# chunk 357 done
# chunk 358 done
# chunk 359 done
# chunk 360 done
# chunk 361 done
# chunk 362 done
# chunk 363 done
# chunk 364 done
# chunk 365 done
# chunk 366 done
# chunk 367 done
# chunk 368 done
# chunk 369 done
# chunk 370 done
# chunk 371 done
# chunk 372 done
# chunk 373 done
# chunk 374 done
# chunk 375 done
# chunk 376 done
# chunk 377 done
# chunk 378 done
# chunk 379 done
# chunk 380 done
# chunk 381 done
# chunk 382 done
# chunk 383 done
# chunk 384 done
# chunk 385 done
# chunk 386 done
# chunk 387 done
# chunk 388 done
# chunk 389 done
# chunk 390 done
# chunk 391 done
# chunk 392 done
# chunk 393 done
# chunk 394 done
# chunk 395 done
# chunk 396 done
# chunk 397 done
# chunk 398 done
# chunk 399 done
# chunk 400 done
# chunk 401 done
# chunk 402 done
# chunk 403 done
# chunk 404 done
# chunk 405 done
# chunk 406 done
# chunk 407 done
# chunk 408 done
# chunk 409 done
# chunk 410 done
# chunk 411 done
# chunk 412 done
# chunk 413 done
# chunk 414 done
# chunk 415 done
# chunk 416 done
# chunk 417 done
# chunk 418 done
# chunk 419 done
# chunk 420 done
# chunk 421 done
# chunk 422 done
# chunk 423 done
# chunk 424 done
# chunk 425 done
# chunk 426 done
# chunk 427 done
# chunk 428 done
# chunk 429 done
# chunk 430 done
# chunk 431 done
# chunk 432 done
# chunk 433 done
# chunk 434 done
# chunk 435 done
# chunk 436 done
# chunk 437 done
# chunk 438 done
# chunk 439 done
# chunk 440 done
# chunk 441 done
# chunk 442 done
# chunk 443 done
# chunk 444 done
# chunk 445 done
# chunk 446 done
# chunk 447 done
# chunk 448 done
# chunk 449 done
# chunk 450 done
# chunk 451 done
# chunk 452 done
# chunk 453 done
# chunk 454 done
# chunk 455 done
# chunk 456 done
# chunk 457 done
# chunk 458 done
# chunk 459 done
# chunk 460 done
# chunk 461 done
# chunk 462 done
# chunk 463 done
# chunk 464 done
# chunk 465 done
# chunk 466 done
# chunk 467 done
# chunk 468 done
# chunk 469 done
# chunk 470 done
# chunk 471 done
# chunk 472 done
# chunk 473 done
# chunk 474 done
# chunk 475 done
# chunk 476 done
# chunk 477 done
# chunk 478 done
# chunk 479 done
# chunk 480 done
# chunk 481 done
# chunk 482 done
# chunk 483 done
# chunk 484 done
# chunk 485 done
# chunk 486 done
# chunk 487 done
# chunk 488 done
# chunk 489 done
# chunk 490 done
# chunk 491 done
# chunk 492 done
# chunk 493 done
# chunk 494 done
# chunk 495 done
# chunk 496 done
# chunk 497 done
# chunk 498 done
# chunk 499 done
# chunk 500 done
# chunk 501 done
# chunk 502 done
# chunk 503 done
# chunk 504 done
# chunk 505 done
# chunk 506 done
# chunk 507 done
# chunk 508 done
# chunk 509 done
# chunk 510 done
# chunk 511 done
# 6167908

# %%
import csv
import sqlite3

def process_csv_files(filepaths, dbname="openalex_db.sqlite"):
    # Connect to SQLite database (this creates the database if it doesn't exist)
    conn = sqlite3.connect(dbname)
    cursor = conn.cursor()

    with open(filepaths[0], 'r', encoding='utf-8') as file:
        csv_reader = csv.reader(file)
        header = next(csv_reader)
        id = header[1]
        columns = header[2:]
        columns = f'{id} PRIMARY KEY, '+', '.join(f'{name} TEXT' for name in columns)
        sql = f'CREATE TABLE IF NOT EXISTS data ({columns})'
        cursor.execute(sql)

    for filepath in filepaths:
        print(f'Processing {filepath}...')
        with open(filepath, 'r', encoding='utf-8') as file:
            csv_reader = csv.DictReader(file)
            for row in csv_reader:
                row_data = {k: v for k, v in row.items() if k in header[1:]}
                print(row_data['id'])
                columns = ', '.join(row_data.keys())
                placeholders = ', '.join('?' * len(row_data))
                sql = f'INSERT OR IGNORE INTO data ({columns}) VALUES ({placeholders})'
                cursor.execute(sql, list(row_data.values()))

    # Commit changes and close the connection
    conn.commit()
    conn.close()

    # Optional: Export data from SQLite to new CSV files
    # This step is omitted for brevity but would involve querying the table
    # and writing the results to one or more CSV files.

# %%
process_csv_files([f"/Volumes/Samsung_T5/OpenAlex_Works/works_chunk_{i}.csv" for i in range(512)])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[118], line 1
# ----> 1 process_csv_files([f"/Volumes/Samsung_T5/OpenAlex_Works/works_chunk_{i}.csv"] for i in range(512))
#
# Cell In[117], line 9, in process_csv_files(filepaths, dbname)
#       6 conn = sqlite3.connect(dbname)
#       7 cursor = conn.cursor()
# ----> 9 with open(filepaths[0], 'r', encoding='utf-8') as file:
#      10     csv_reader = csv.reader(file)
#      11     header = next(csv_reader)
#
# TypeError: 'generator' object is not subscriptable

# %%
conn = sqlite3.connect("/Volumes/Samsung_T5/OpenAlex_Works/openalex_db.sqlite")
cur = conn.cursor()
cur.execute("SELECT COUNT(*) FROM data")

# %%
cur.fetchall()
# Out:
# [(37520,)]

# %%
with open('/Volumes/Samsung_T5/OpenAlex_Works/works_chunk_0.csv', 'r', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    header = next(csv_reader)
    id = header[1]
    columns = header[2:]
    columns = f'{id} PRIMARY KEY, '+', '.join(f'{name} TEXT' for name in columns)

print(columns)
# Out:
# id PRIMARY KEY, doi TEXT, title TEXT, display_name TEXT, publication_year TEXT, publication_date TEXT, ids TEXT, language TEXT, primary_location TEXT, type TEXT, type_crossref TEXT, indexed_in TEXT, open_access TEXT, authorships TEXT, countries_distinct_count TEXT, institutions_distinct_count TEXT, corresponding_author_ids TEXT, corresponding_institution_ids TEXT, apc_list TEXT, apc_paid TEXT, has_fulltext TEXT, fulltext_origin TEXT, cited_by_count TEXT, cited_by_percentile_year TEXT, biblio TEXT, is_retracted TEXT, is_paratext TEXT, primary_topic TEXT, topics TEXT, keywords TEXT, concepts TEXT, mesh TEXT, locations_count TEXT, locations TEXT, best_oa_location TEXT, sustainable_development_goals TEXT, grants TEXT, referenced_works_count TEXT, referenced_works TEXT, related_works TEXT, ngrams_url TEXT, abstract_inverted_index TEXT, cited_by_api_url TEXT, counts_by_year TEXT, updated_date TEXT, created_date TEXT, is_authors_truncated TEXT

# %%
chunk_0.to_json('chunk_0.json', orient='records', lines=True)

# %%
chunk_0_json = pd.read_json('chunk_0.json', lines=True)

# %%
chunk_0.to_parquet('chunk_0.parquet')

# %%
chunk_0_parquet = pd.read_parquet('chunk_0.parquet')

# %%
chunk_0_parquet
# Out:
#        Unnamed: 0                                id  \
# 0               0  https://openalex.org/W2256016639
# 1               1  https://openalex.org/W2097950056
# 2               2  https://openalex.org/W2112334970
# 3               3  https://openalex.org/W2909678677
# 4               4  https://openalex.org/W2115830594
# ...           ...                               ...
# 14750           0  https://openalex.org/W3147227403
# 14751           1  https://openalex.org/W3168899959
# 14752           2   https://openalex.org/W325855580
# 14753           3  https://openalex.org/W4247458054
# 14754           4    https://openalex.org/W49606109
#
#                                                  doi  \
# 0                https://doi.org/10.1038/nature19057
# 1      https://doi.org/10.1016/s0140-6736(12)61689-4
# 2      https://doi.org/10.1016/s0140-6736(96)07492-2
# 3      https://doi.org/10.1016/s0140-6736(18)31788-4
# 4      https://doi.org/10.1016/s0140-6736(06)68770-9
# ...                                              ...
# 14750                                           None
# 14751                                           None
# 14752                                           None
# 14753               https://doi.org/10.2307/25512956
# 14754                                           None
#
#                                                    title  \
# 0      Analysis of protein-coding genetic variation i...
# 1      Disability-adjusted life years (DALYs) for 291...
# 2      Alternative projections of mortality and disab...
# 3      Food in the Anthropocene: the EAT–Lancet Commi...
# 4      Global and regional burden of disease and risk...
# ...                                                  ...
# 14750                          Astrophysics with MILAGRO
# 14751  Search for Emission of Ultra High Energy Radia...
# 14752  Simulations of multiparticle production at hig...
# 14753                                    The Herne's Egg
# 14754  Rapport sur le developpement dans le monde 199...
#
#                                             display_name  publication_year  \
# 0      Analysis of protein-coding genetic variation i...              2016
# 1      Disability-adjusted life years (DALYs) for 291...              2012
# 2      Alternative projections of mortality and disab...              1997
# 3      Food in the Anthropocene: the EAT–Lancet Commi...              2019
# 4      Global and regional burden of disease and risk...              2006
# ...                                                  ...               ...
# 14750                          Astrophysics with MILAGRO              1993
# 14751  Search for Emission of Ultra High Energy Radia...              1993
# 14752  Simulations of multiparticle production at hig...              1993
# 14753                                    The Herne's Egg              1993
# 14754  Rapport sur le developpement dans le monde 199...              1993
#
#       publication_date                                                ids  \
# 0           2016-08-01  {'openalex': 'https://openalex.org/W2256016639...
# 1           2012-12-01  {'openalex': 'https://openalex.org/W2097950056...
# 2           1997-05-01  {'openalex': 'https://openalex.org/W2112334970...
# 3           2019-02-01  {'openalex': 'https://openalex.org/W2909678677...
# 4           2006-05-01  {'openalex': 'https://openalex.org/W2115830594...
# ...                ...                                                ...
# 14750       1993-01-01  {'openalex': 'https://openalex.org/W3147227403...
# 14751       1993-05-01  {'openalex': 'https://openalex.org/W3168899959...
# 14752       1993-06-15  {'openalex': 'https://openalex.org/W325855580'...
# 14753       1993-01-01  {'openalex': 'https://openalex.org/W4247458054...
# 14754       1993-07-01  {'openalex': 'https://openalex.org/W49606109',...
#
#       language                                   primary_location  ...  \
# 0           en  {'is_oa': True, 'landing_page_url': 'https://d...  ...
# 1           en  {'is_oa': False, 'landing_page_url': 'https://...  ...
# 2           en  {'is_oa': False, 'landing_page_url': 'https://...  ...
# 3           en  {'is_oa': False, 'landing_page_url': 'https://...  ...
# 4           en  {'is_oa': False, 'landing_page_url': 'https://...  ...
# ...        ...                                                ...  ...
# 14750       en  {'is_oa': False, 'landing_page_url': 'http://u...  ...
# 14751       en  {'is_oa': False, 'landing_page_url': 'https://...  ...
# 14752       en  {'is_oa': False, 'landing_page_url': 'http://w...  ...
# 14753     None  {'is_oa': False, 'landing_page_url': 'https://...  ...
# 14754       en  {'is_oa': False, 'landing_page_url': 'https://...  ...
#
#                                         referenced_works  \
# 0      ['https://openalex.org/W1533942137', 'https://...
# 1      ['https://openalex.org/W1503206236', 'https://...
# 2      ['https://openalex.org/W1565391189', 'https://...
# 3      ['https://openalex.org/W595212506', 'https://o...
# 4      ['https://openalex.org/W1981986207', 'https://...
# ...                                                  ...
# 14750                                                 []
# 14751                                                 []
# 14752                                                 []
# 14753                                                 []
# 14754                                                 []
#
#                                            related_works  \
# 0      ['https://openalex.org/W2484239316', 'https://...
# 1      ['https://openalex.org/W2131839676', 'https://...
# 2      ['https://openalex.org/W2056522719', 'https://...
# 3      ['https://openalex.org/W4200315805', 'https://...
# 4      ['https://openalex.org/W2131839676', 'https://...
# ...                                                  ...
# 14750  ['https://openalex.org/W346237057', 'https://o...
# 14751  ['https://openalex.org/W126798772', 'https://o...
# 14752  ['https://openalex.org/W72940282', 'https://op...
# 14753  ['https://openalex.org/W2082860237', 'https://...
# 14754                                                 []
#
#                                               ngrams_url  \
# 0      https://api.openalex.org/works/W2256016639/ngrams
# 1      https://api.openalex.org/works/W2097950056/ngrams
# 2      https://api.openalex.org/works/W2112334970/ngrams
# 3      https://api.openalex.org/works/W2909678677/ngrams
# 4      https://api.openalex.org/works/W2115830594/ngrams
# ...                                                  ...
# 14750  https://api.openalex.org/works/W3147227403/ngrams
# 14751  https://api.openalex.org/works/W3168899959/ngrams
# 14752   https://api.openalex.org/works/W325855580/ngrams
# 14753  https://api.openalex.org/works/W4247458054/ngrams
# 14754    https://api.openalex.org/works/W49606109/ngrams
#
#                                  abstract_inverted_index  \
# 0      {'Large-scale': [0], 'reference': [1], 'data':...
# 1      {'Background': [0], 'Measuring': [1], 'disease...
# 2      {'Plausible': [0], 'projections': [1, 150, 204...
# 3      {'Food': [0, 207, 241, 310, 337, 353, 386, 483...
# 4      {'Our': [0, 322], 'aim': [1], 'was': [2, 157, ...
# ...                                                  ...
# 14750                                               None
# 14751                                               None
# 14752  {'A': [0], 'Monte': [1], 'Carlo': [2], 'genera...
# 14753                                               None
# 14754  {'This': [0, 131], 'is': [1, 39, 49, 76, 226],...
#
#                                         cited_by_api_url  \
# 0      https://api.openalex.org/works?filter=cites:W2...
# 1      https://api.openalex.org/works?filter=cites:W2...
# 2      https://api.openalex.org/works?filter=cites:W2...
# 3      https://api.openalex.org/works?filter=cites:W2...
# 4      https://api.openalex.org/works?filter=cites:W2...
# ...                                                  ...
# 14750  https://api.openalex.org/works?filter=cites:W3...
# 14751  https://api.openalex.org/works?filter=cites:W3...
# 14752  https://api.openalex.org/works?filter=cites:W3...
# 14753  https://api.openalex.org/works?filter=cites:W4...
# 14754  https://api.openalex.org/works?filter=cites:W4...
#
#                                           counts_by_year  \
# 0      [{'year': 2024, 'cited_by_count': 42}, {'year'...
# 1      [{'year': 2024, 'cited_by_count': 34}, {'year'...
# 2      [{'year': 2024, 'cited_by_count': 5}, {'year':...
# 3      [{'year': 2024, 'cited_by_count': 135}, {'year...
# 4      [{'year': 2024, 'cited_by_count': 13}, {'year'...
# ...                                                  ...
# 14750                                                 []
# 14751                                                 []
# 14752                                                 []
# 14753                                                 []
# 14754                                                 []
#
#                      updated_date created_date is_authors_truncated  \
# 0      2024-02-09T16:01:28.162872   2016-06-24                 None
# 1      2024-02-09T15:44:30.115740   2016-06-24                 True
# 2      2024-02-03T01:09:06.322989   2016-06-24                 None
# 3      2024-02-06T14:32:49.072483   2019-01-25                 None
# 4      2024-02-04T11:52:57.006034   2016-06-24                 None
# ...                           ...          ...                  ...
# 14750  2024-02-07T14:06:39.790932   2021-04-13                 None
# 14751  2024-02-09T02:45:52.138393   2021-06-22                 None
# 14752  2024-02-06T08:24:28.741848   2016-06-24                 None
# 14753  2024-02-02T14:47:22.326577   2022-05-12                 None
# 14754  2024-02-04T04:44:43.721923   2016-06-24                 None
#
#                                               author_ids
# 0      [https://openalex.org/A5021736013, https://ope...
# 1      [https://openalex.org/A5004515522, https://ope...
# 2      [https://openalex.org/A5004515522, https://ope...
# 3      [https://openalex.org/A5083991449, https://ope...
# 4      [https://openalex.org/A5042384828, https://ope...
# ...                                                  ...
# 14750  [https://openalex.org/A5025839822, https://ope...
# 14751  [https://openalex.org/A5046416298, https://ope...
# 14752                 [https://openalex.org/A5013110276]
# 14753  [https://openalex.org/A5004515522, https://ope...
# 14754  [https://openalex.org/A5020849392, https://ope...
#
# [14755 rows x 49 columns]

# %%
chunk_0.to_pickle('chunk_0.pkl')

# %%
chunk_0_pickle = pd.read_pickle('chunk_0.pkl')

# %%
chunk_0_pickle
# Out:
#        Unnamed: 0                                id  \
# 0               0  https://openalex.org/W2256016639
# 1               1  https://openalex.org/W2097950056
# 2               2  https://openalex.org/W2112334970
# 3               3  https://openalex.org/W2909678677
# 4               4  https://openalex.org/W2115830594
# ...           ...                               ...
# 14750           0  https://openalex.org/W3147227403
# 14751           1  https://openalex.org/W3168899959
# 14752           2   https://openalex.org/W325855580
# 14753           3  https://openalex.org/W4247458054
# 14754           4    https://openalex.org/W49606109
#
#                                                  doi  \
# 0                https://doi.org/10.1038/nature19057
# 1      https://doi.org/10.1016/s0140-6736(12)61689-4
# 2      https://doi.org/10.1016/s0140-6736(96)07492-2
# 3      https://doi.org/10.1016/s0140-6736(18)31788-4
# 4      https://doi.org/10.1016/s0140-6736(06)68770-9
# ...                                              ...
# 14750                                            NaN
# 14751                                            NaN
# 14752                                            NaN
# 14753               https://doi.org/10.2307/25512956
# 14754                                            NaN
#
#                                                    title  \
# 0      Analysis of protein-coding genetic variation i...
# 1      Disability-adjusted life years (DALYs) for 291...
# 2      Alternative projections of mortality and disab...
# 3      Food in the Anthropocene: the EAT–Lancet Commi...
# 4      Global and regional burden of disease and risk...
# ...                                                  ...
# 14750                          Astrophysics with MILAGRO
# 14751  Search for Emission of Ultra High Energy Radia...
# 14752  Simulations of multiparticle production at hig...
# 14753                                    The Herne's Egg
# 14754  Rapport sur le developpement dans le monde 199...
#
#                                             display_name  publication_year  \
# 0      Analysis of protein-coding genetic variation i...              2016
# 1      Disability-adjusted life years (DALYs) for 291...              2012
# 2      Alternative projections of mortality and disab...              1997
# 3      Food in the Anthropocene: the EAT–Lancet Commi...              2019
# 4      Global and regional burden of disease and risk...              2006
# ...                                                  ...               ...
# 14750                          Astrophysics with MILAGRO              1993
# 14751  Search for Emission of Ultra High Energy Radia...              1993
# 14752  Simulations of multiparticle production at hig...              1993
# 14753                                    The Herne's Egg              1993
# 14754  Rapport sur le developpement dans le monde 199...              1993
#
#       publication_date                                                ids  \
# 0           2016-08-01  {'openalex': 'https://openalex.org/W2256016639...
# 1           2012-12-01  {'openalex': 'https://openalex.org/W2097950056...
# 2           1997-05-01  {'openalex': 'https://openalex.org/W2112334970...
# 3           2019-02-01  {'openalex': 'https://openalex.org/W2909678677...
# 4           2006-05-01  {'openalex': 'https://openalex.org/W2115830594...
# ...                ...                                                ...
# 14750       1993-01-01  {'openalex': 'https://openalex.org/W3147227403...
# 14751       1993-05-01  {'openalex': 'https://openalex.org/W3168899959...
# 14752       1993-06-15  {'openalex': 'https://openalex.org/W325855580'...
# 14753       1993-01-01  {'openalex': 'https://openalex.org/W4247458054...
# 14754       1993-07-01  {'openalex': 'https://openalex.org/W49606109',...
#
#       language                                   primary_location  ...  \
# 0           en  {'is_oa': True, 'landing_page_url': 'https://d...  ...
# 1           en  {'is_oa': False, 'landing_page_url': 'https://...  ...
# 2           en  {'is_oa': False, 'landing_page_url': 'https://...  ...
# 3           en  {'is_oa': False, 'landing_page_url': 'https://...  ...
# 4           en  {'is_oa': False, 'landing_page_url': 'https://...  ...
# ...        ...                                                ...  ...
# 14750       en  {'is_oa': False, 'landing_page_url': 'http://u...  ...
# 14751       en  {'is_oa': False, 'landing_page_url': 'https://...  ...
# 14752       en  {'is_oa': False, 'landing_page_url': 'http://w...  ...
# 14753      NaN  {'is_oa': False, 'landing_page_url': 'https://...  ...
# 14754       en  {'is_oa': False, 'landing_page_url': 'https://...  ...
#
#                                         referenced_works  \
# 0      ['https://openalex.org/W1533942137', 'https://...
# 1      ['https://openalex.org/W1503206236', 'https://...
# 2      ['https://openalex.org/W1565391189', 'https://...
# 3      ['https://openalex.org/W595212506', 'https://o...
# 4      ['https://openalex.org/W1981986207', 'https://...
# ...                                                  ...
# 14750                                                 []
# 14751                                                 []
# 14752                                                 []
# 14753                                                 []
# 14754                                                 []
#
#                                            related_works  \
# 0      ['https://openalex.org/W2484239316', 'https://...
# 1      ['https://openalex.org/W2131839676', 'https://...
# 2      ['https://openalex.org/W2056522719', 'https://...
# 3      ['https://openalex.org/W4200315805', 'https://...
# 4      ['https://openalex.org/W2131839676', 'https://...
# ...                                                  ...
# 14750  ['https://openalex.org/W346237057', 'https://o...
# 14751  ['https://openalex.org/W126798772', 'https://o...
# 14752  ['https://openalex.org/W72940282', 'https://op...
# 14753  ['https://openalex.org/W2082860237', 'https://...
# 14754                                                 []
#
#                                               ngrams_url  \
# 0      https://api.openalex.org/works/W2256016639/ngrams
# 1      https://api.openalex.org/works/W2097950056/ngrams
# 2      https://api.openalex.org/works/W2112334970/ngrams
# 3      https://api.openalex.org/works/W2909678677/ngrams
# 4      https://api.openalex.org/works/W2115830594/ngrams
# ...                                                  ...
# 14750  https://api.openalex.org/works/W3147227403/ngrams
# 14751  https://api.openalex.org/works/W3168899959/ngrams
# 14752   https://api.openalex.org/works/W325855580/ngrams
# 14753  https://api.openalex.org/works/W4247458054/ngrams
# 14754    https://api.openalex.org/works/W49606109/ngrams
#
#                                  abstract_inverted_index  \
# 0      {'Large-scale': [0], 'reference': [1], 'data':...
# 1      {'Background': [0], 'Measuring': [1], 'disease...
# 2      {'Plausible': [0], 'projections': [1, 150, 204...
# 3      {'Food': [0, 207, 241, 310, 337, 353, 386, 483...
# 4      {'Our': [0, 322], 'aim': [1], 'was': [2, 157, ...
# ...                                                  ...
# 14750                                                NaN
# 14751                                                NaN
# 14752  {'A': [0], 'Monte': [1], 'Carlo': [2], 'genera...
# 14753                                                NaN
# 14754  {'This': [0, 131], 'is': [1, 39, 49, 76, 226],...
#
#                                         cited_by_api_url  \
# 0      https://api.openalex.org/works?filter=cites:W2...
# 1      https://api.openalex.org/works?filter=cites:W2...
# 2      https://api.openalex.org/works?filter=cites:W2...
# 3      https://api.openalex.org/works?filter=cites:W2...
# 4      https://api.openalex.org/works?filter=cites:W2...
# ...                                                  ...
# 14750  https://api.openalex.org/works?filter=cites:W3...
# 14751  https://api.openalex.org/works?filter=cites:W3...
# 14752  https://api.openalex.org/works?filter=cites:W3...
# 14753  https://api.openalex.org/works?filter=cites:W4...
# 14754  https://api.openalex.org/works?filter=cites:W4...
#
#                                           counts_by_year  \
# 0      [{'year': 2024, 'cited_by_count': 42}, {'year'...
# 1      [{'year': 2024, 'cited_by_count': 34}, {'year'...
# 2      [{'year': 2024, 'cited_by_count': 5}, {'year':...
# 3      [{'year': 2024, 'cited_by_count': 135}, {'year...
# 4      [{'year': 2024, 'cited_by_count': 13}, {'year'...
# ...                                                  ...
# 14750                                                 []
# 14751                                                 []
# 14752                                                 []
# 14753                                                 []
# 14754                                                 []
#
#                      updated_date created_date is_authors_truncated  \
# 0      2024-02-09T16:01:28.162872   2016-06-24                  NaN
# 1      2024-02-09T15:44:30.115740   2016-06-24                 True
# 2      2024-02-03T01:09:06.322989   2016-06-24                  NaN
# 3      2024-02-06T14:32:49.072483   2019-01-25                  NaN
# 4      2024-02-04T11:52:57.006034   2016-06-24                  NaN
# ...                           ...          ...                  ...
# 14750  2024-02-07T14:06:39.790932   2021-04-13                  NaN
# 14751  2024-02-09T02:45:52.138393   2021-06-22                  NaN
# 14752  2024-02-06T08:24:28.741848   2016-06-24                  NaN
# 14753  2024-02-02T14:47:22.326577   2022-05-12                  NaN
# 14754  2024-02-04T04:44:43.721923   2016-06-24                  NaN
#
#                                               author_ids
# 0      [https://openalex.org/A5021736013, https://ope...
# 1      [https://openalex.org/A5004515522, https://ope...
# 2      [https://openalex.org/A5004515522, https://ope...
# 3      [https://openalex.org/A5083991449, https://ope...
# 4      [https://openalex.org/A5042384828, https://ope...
# ...                                                  ...
# 14750  [https://openalex.org/A5025839822, https://ope...
# 14751  [https://openalex.org/A5046416298, https://ope...
# 14752                 [https://openalex.org/A5013110276]
# 14753  [https://openalex.org/A5004515522, https://ope...
# 14754  [https://openalex.org/A5020849392, https://ope...
#
# [14755 rows x 49 columns]
